# %%
import pandas as pd

# %%
data = pd.read_excel("First_2000_abstract_clean.xlsx", index_col=0)
data
# Out:
#        Publication Type                                            Authors  \
# 1.0                   C                         Purnamasari, E; Sudarno, S
# 2.0                   J                                          McGee, JA
# 3.0                   C                           Kononenko, K; Demidov, D
# 4.0                   J                Chianese, DS; Rotz, CA; Richard, TL
# 5.0                   J  De Gryze, S; Albarracin, MV; Catala-Luque, R; ...
# ...                 ...                                                ...
# 1996.0                J                     Edberg, S; Tigabu, M; Oden, PC
# 1997.0                J  Karki, S; Adviento-Borbe, MAA; Massey, JH; Reb...
# 1998.0                J  Kollah, B; Dubey, G; Parasai, P; Saha, JK; Gan...
# 1999.0                J  Bregaglio, S; Mongiano, G; Ferrara, RM; Ginald...
# 2000.0                J   Colley, TA; Olsen, SI; Birkved, M; Hauschild, MZ
#
#                                             Article Title  \
# 1.0     Analysis of Greenhouse Gas Reduction by Using ...
# 2.0     Does certified organic farming reduce greenhou...
# 3.0     USE OF ARTIFICIAL NEURAL NETWORKS TO PREDICT G...
# 4.0     SIMULATION OF NITROUS OXIDE EMISSIONS FROM DAI...
# 5.0     Modeling shows that alternative soil managemen...
# ...                                                   ...
# 1996.0  Commercial Eucalyptus Plantations with Taungya...
# 1997.0  Assessing Seasonal Methane and Nitrous Oxide E...
# 1998.0  Interactive effect of biochar size and organic...
# 1999.0  Which are the most favourable conditions for r...
# 2000.0  Delta Life Cycle Assessment of Regenerative Ag...
#
#                                             Abstract (AB)  Publication Year  \
# 1.0     Agriculture contributes approximately 14% of g...            2018.0
# 2.0     The increasing prevalence of ecologically sust...            2015.0
# 3.0     Agriculture has a greater impact on the enviro...            2020.0
# 4.0     Farming practices can have a large impact on t...            2009.0
# 5.0     Agricultural management has a significant impa...            2009.0
# ...                                                   ...               ...
# 1996.0  The increasing demand for wood, fiber, and pul...            2022.0
# 1997.0  Improved irrigation management is identified a...            2021.0
# 1998.0  Biochar (BC) application to agricultural soil ...            2015.0
# 1999.0  No-tillage practices have a recognised benefic...            2022.0
# 2000.0  Regenerative agriculture is being used by a sm...            2020.0
#
#                                          DOI Researcher1 Researcher2  \
# 1.0              10.1051/e3sconf/20187308005     INCLUDE     INCLUDE
# 2.0                10.1007/s10460-014-9543-1     INCLUDE     INCLUDE
# 3.0             10.22616/ERDev.2020.19.TF213     EXCLUDE     EXCLUDE
# 4.0                                      NaN     INCLUDE     EXCLUDE
# 5.0                    10.3733/ca.v063n02p84     INCLUDE     INCLUDE
# ...                                      ...         ...         ...
# 1996.0                     10.3390/f13091395     INCLUDE         NaN
# 1997.0           10.3390/agriculture11030261     INCLUDE         NaN
# 1998.0                     10.1111/sum.12168     EXCLUDE         NaN
# 1999.0  10.1016/j.iswcr.2022.05.0032095-6339     INCLUDE         NaN
# 2000.0                     10.1002/ieam.4238     INCLUDE         NaN
#
#        Researcher3 Final decision Review studies Duplicates
# 1.0            NaN        INCLUDE            NaN        NaN
# 2.0            NaN        INCLUDE            NaN        NaN
# 3.0            NaN        EXCLUDE            NaN        NaN
# 4.0            NaN        EXCLUDE            NaN        NaN
# 5.0            NaN        INCLUDE            NaN        NaN
# ...            ...            ...            ...        ...
# 1996.0     INCLUDE        INCLUDE            NaN        NaN
# 1997.0     INCLUDE        INCLUDE            NaN        NaN
# 1998.0     EXCLUDE        EXCLUDE            NaN        NaN
# 1999.0     INCLUDE        INCLUDE         Review        NaN
# 2000.0     INCLUDE        INCLUDE            NaN        NaN
#
# [2000 rows x 12 columns]

# %%
data["Final decision"].value_counts()
# Out:
# EXCLUDE    1004
# INCLUDE     996
# Name: Final decision, dtype: int64

# %%
chatgpt_train_sample = data.sample(100, random_state=2023)
chatgpt_train_sample
# Out:
#        Publication Type                                            Authors  \
# 232.0                 J                   Tang, K; He, CT; Ma, CB; Wang, D
# 1761.0                J  Allam, M; Radicetti, E; Quintarelli, V; Petros...
# 792.0                 J     Raihan, A; Said, MNM; Abdullah, SMS; Begum, RA
# 405.0                 J  Wen, Y; Zang, HD; Freeman, B; Ma, QX; Chadwick...
# 1396.0                J        Dhanda, S; Yadav, A; Yadav, DB; Chauhan, BS
# ...                 ...                                                ...
# 1758.0                J  Carter, MS; Hauggaard-Nielsen, H; Heiske, S; J...
# 82.0                  J               Huang, JX; Chen, YQ; Sui, P; Gao, WS
# 526.0                 J                                         Everest, B
# 1795.0                J                Gancone, A; Pubule, J; Blumberga, D
# 1179.0                J  Tian, Z; Niu, YL; Fan, DL; Sun, LX; Ficsher, G...
#
#                                             Article Title  \
# 232.0   Does carbon farming provide a cost-effective o...
# 1761.0  Influence of Organic and Mineral Fertilizers o...
# 792.0   Climate Change Mitigation Options in the Fores...
# 405.0   Rye cover crop incorporation and high watertab...
# 1396.0  Emerging Issues and Potential Opportunities in...
# ...                                                   ...
# 1758.0  Consequences of field N2O emissions for the en...
# 82.0    Estimation of net greenhouse gas balance using...
# 526.0   Farmers' adaptation to climate-smart agricultu...
# 1795.0  Valorization Methodology for Agriculture Secto...
# 1179.0  Maintaining rice production while mitigating m...
#
#                                             Abstract (AB)  Publication Year  \
# 232.0   In this study, we apply a whole farm bioeconom...            2019.0
# 1761.0  The intensive use of mineral (M) fertilizers m...            2022.0
# 792.0   The Intergovernmental Panel on Climate Change ...            2018.0
# 405.0   Drainage and cultivation of peat soils almost ...            2019.0
# 1396.0  The rice-wheat cropping system (RWCS) is the b...            2022.0
# ...                                                   ...               ...
# 1758.0  One way of reducing the emissions of fossil fu...            2012.0
# 82.0    The net greenhouse gas balance (NGHGB), estima...            2013.0
# 526.0   Some of the measures to be taken to reduce gre...            2021.0
# 1795.0  Agriculture sector holds an essential role in ...            2021.0
# 1179.0  China is the largest rice producing and consum...            2018.0
#
#                                      DOI Researcher1 Researcher2 Researcher3  \
# 232.0            10.1111/1467-8489.12306     INCLUDE         NaN     INCLUDE
# 1761.0       10.3390/agriculture12040464     INCLUDE         NaN     INCLUDE
# 792.0      10.17576/jkukm-2018-si1(6)-11     EXCLUDE         NaN     EXCLUDE
# 405.0                   10.1002/ldr.3390         NaN     INCLUDE     INCLUDE
# 1396.0          10.3389/fpls.2022.832683         NaN     EXCLUDE     EXCLUDE
# ...                                  ...         ...         ...         ...
# 1758.0  10.1111/j.1757-1707.2011.01132.x     INCLUDE         NaN     INCLUDE
# 82.0     10.1016/j.scitotenv.2013.03.035     INCLUDE     INCLUDE         NaN
# 526.0         10.1007/s10668-020-00767-1         NaN     INCLUDE     INCLUDE
# 1795.0          10.2478/rtuect-2021-0071     EXCLUDE         NaN     EXCLUDE
# 1179.0        10.1016/j.agsy.2017.04.006     EXCLUDE     INCLUDE     EXCLUDE
#
#        Final decision Review studies Duplicates
# 232.0         INCLUDE            NaN        NaN
# 1761.0        INCLUDE         Review        NaN
# 792.0         EXCLUDE            NaN        NaN
# 405.0         INCLUDE            NaN        NaN
# 1396.0        EXCLUDE            NaN        NaN
# ...               ...            ...        ...
# 1758.0        INCLUDE            NaN        NaN
# 82.0          INCLUDE            NaN        NaN
# 526.0         INCLUDE            NaN        NaN
# 1795.0        EXCLUDE            NaN        NaN
# 1179.0        EXCLUDE            NaN        NaN
#
# [100 rows x 12 columns]

# %%
import os
import openai
import time

# %%
openai.organization = ""#"X"
openai.api_key = "X"
openai.Model.list()

# %%
def chatgpt(text, temp=0.7, max_t=5):
    try: 
        output = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                  {"role": "system", "content": text},
            ],
            temperature=temp,
            max_tokens=max_t,
            top_p=1.0,
            frequency_penalty=0.0,
            presence_penalty=0.0
        )
        openai.Completion.create(
            model="text-davinci-003",
            prompt=text,

        )
    except:
        print("Thinking...")
        time.sleep(1)
        return chatgpt(text, temp=temp, max_t=max_t)
    return output

# %%
template = lambda t, a, b: f"""Title: {t}
Abstract: {a}
Based on the abstract/title, {b.replace("article", "abstract")} (think step by step and answer "Yes" or "No")"""
t = chatgpt_train_sample["Article Title"].iloc[0] 
a = chatgpt_train_sample["Abstract (AB)"].iloc[0]
b = "Does the article discuss agroecological practices?"
b = b.replace("article", "abstract")
prompt = template(t, a, b)
print(prompt)
# Out:
# Title: Does carbon farming provide a cost-effective option to mitigate GHG emissions? Evidence from China
# Abstract: In this study, we apply a whole farm bioeconomic analysis to explore the changes in land use, farm practices and on-farm greenhouse gas (GHG) emission under varying levels of agricultural greenhouse gas abatement incentives in the form of a carbon tax for a semi-arid crop-livestock farming system in China's Loess Plateau. Our results show that the optimised agricultural enterprises move towards being cropping-dominated reducing on-farm emission since livestock perform is the major source of emission. Farmers employ less oats-based and rapeseed-based rotations but more dry pea-based rotations in the optimal enterprise mix. A substantial reduction in on-farm greenhouse gas emission can be achieved at low cost with a small increase in carbon incentives. Our estimates indicate that crop-livestock farmers in China's Loess Plateau may reduce their on-farm GHG emission between 16.6 and 33 per cent with marginal abatement costs <100/t CO(2)e and 150/t CO(2)e in 2015 Chinese Yuan. The analysis implies that reducing greenhouse gas emission in China's semi-arid crop-livestock agriculture is potentially a low-cost option.
# Based on the abstract/title, Does the abstract discuss agroecological practices? (think step by step and answer "Yes" or "No")

# %%
# %%time
chatgpt(prompt, temp=0.7, max_t=5)["choices"][0]["message"]["content"]
# Out:
# Wall time: 870 ms
# 'Yes'

# %%
# %%time
b = "Does the article discuss agroecological practices?"
b = b.replace("article", "abstract")
responses = []
for i, ix in enumerate(chatgpt_train_sample.index):
    t, a, label = chatgpt_train_sample.loc[ix]["Article Title  Abstract (AB)  Final decision".split("  ")]
    a = a.replace("\n", " ")
    a = " ".join(a.split(" ")).strip()
    o = chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
    o = o.replace("\n", " ").strip()
    responses.append([ix, o])
    print(100*(i+1)/chatgpt_train_sample.shape[0], ix, o, label)
# Out:
# 1.0 232.0 Yes INCLUDE
# 2.0 1761.0 Yes. INCLUDE
# 3.0 792.0 Yes EXCLUDE
# 4.0 405.0 Yes INCLUDE
# 5.0 1396.0 Yes. EXCLUDE
# 6.0 433.0 There is no mention of EXCLUDE
# 7.0 543.0 No. EXCLUDE
# 8.0 412.0 Yes INCLUDE
# 9.0 1397.0 Yes EXCLUDE
# 10.0 688.0 Yes INCLUDE
# 11.0 743.0 Yes. EXCLUDE
# 12.0 1222.0 No. EXCLUDE
# 13.0 329.0 Yes EXCLUDE
# 14.0 1365.0 Yes EXCLUDE
# 15.0 677.0 No INCLUDE
# 16.0 1432.0 No. INCLUDE
# 17.0 507.0 Yes EXCLUDE
# 18.0 1302.0 Yes. EXCLUDE
# 19.0 847.0 Yes INCLUDE
# 20.0 1580.0 Yes EXCLUDE
# 21.0 1700.0 Yes EXCLUDE
# 22.0 920.0 Yes INCLUDE
# 23.0 987.0 Yes INCLUDE
# 24.0 1673.0 Yes INCLUDE
# 25.0 312.0 Yes INCLUDE
# 26.0 444.0 Yes EXCLUDE
# 27.0 1171.0 Yes INCLUDE
# 28.0 1448.0 Yes. EXCLUDE
# 29.0 1808.0 Yes EXCLUDE
# 30.0 734.0 Yes INCLUDE
# 31.0 430.0 Yes INCLUDE
# 32.0 423.0 Yes. INCLUDE
# 33.0 718.0 No. EXCLUDE
# 34.0 828.0 Yes. EXCLUDE
# 35.0 124.0 Yes. EXCLUDE
# 36.0 1088.0 Yes. EXCLUDE
# 37.0 1172.0 Yes EXCLUDE
# 38.0 38.0 Yes. INCLUDE
# 39.0 355.0 Yes. EXCLUDE
# 40.0 1460.0 Yes. EXCLUDE
# 41.0 930.0 No. EXCLUDE
# 42.0 574.0 Yes. EXCLUDE
# 43.0 168.0 Yes INCLUDE
# 44.0 362.0 Yes INCLUDE
# 45.0 1136.0 Yes. INCLUDE
# 46.0 502.0 Yes EXCLUDE
# 47.0 169.0 Yes EXCLUDE
# 48.0 1979.0 Yes INCLUDE
# 49.0 324.0 Yes INCLUDE
# 50.0 1546.0 No. INCLUDE
# 51.0 1099.0 Yes INCLUDE
# 52.0 1187.0 Yes EXCLUDE
# 53.0 892.0 Yes EXCLUDE
# 54.0 691.0 Yes. EXCLUDE
# 55.0 1380.0 Yes. EXCLUDE
# 56.0 1841.0 Yes INCLUDE
# 57.0 177.0 Yes. INCLUDE
# 58.0 1563.0 Yes INCLUDE
# 59.0 1893.0 No. EXCLUDE
# 60.0 254.0 No EXCLUDE
# 61.0 34.0 Yes EXCLUDE
# 62.0 325.0 Yes. EXCLUDE
# 63.0 222.0 Yes. EXCLUDE
# 64.0 1671.0 Yes. INCLUDE
# 65.0 114.0 No. EXCLUDE
# 66.0 126.0 No EXCLUDE
# 67.0 215.0 Yes INCLUDE
# 68.0 785.0 No EXCLUDE
# 69.0 894.0 Yes INCLUDE
# 70.0 1793.0 Yes INCLUDE
# 71.0 316.0 Yes. EXCLUDE
# 72.0 1727.0 Yes. INCLUDE
# Thinking...
# 73.0 320.0 Yes. EXCLUDE
# 74.0 204.0 Yes EXCLUDE
# 75.0 565.0 Yes. INCLUDE
# 76.0 1665.0 Yes. EXCLUDE
# 77.0 144.0 Yes INCLUDE
# 78.0 343.0 Yes. INCLUDE
# 79.0 1748.0 Yes EXCLUDE
# 80.0 1619.0 Yes. INCLUDE
# 81.0 1057.0 Yes. EXCLUDE
# 82.0 890.0 Yes EXCLUDE
# 83.0 1659.0 No EXCLUDE
# 84.0 1543.0 Yes EXCLUDE
# 85.0 1216.0 No. EXCLUDE
# 86.0 616.0 No. EXCLUDE
# 87.0 1314.0 Yes. INCLUDE
# 88.0 510.0 Yes INCLUDE
# 89.0 73.0 Yes EXCLUDE
# 90.0 1245.0 Yes INCLUDE
# 91.0 1871.0 No. INCLUDE
# 92.0 1472.0 Yes EXCLUDE
# 93.0 371.0 Yes. INCLUDE
# 94.0 604.0 Yes. INCLUDE
# 95.0 889.0 Yes. EXCLUDE
# 96.0 1758.0 Yes INCLUDE
# 97.0 82.0 Yes. INCLUDE
# 98.0 526.0 Yes. INCLUDE
# 99.0 1795.0 No. EXCLUDE
# 100.0 1179.0 Yes EXCLUDE
# Wall time: 7min 48s

# %%
train_b1 = chatgpt_train_sample.copy()
train_b1["chatgpt"] = [x[1] for x in responses]
train_b1
# Out:
#        Publication Type                                            Authors  \
# 232.0                 J                   Tang, K; He, CT; Ma, CB; Wang, D
# 1761.0                J  Allam, M; Radicetti, E; Quintarelli, V; Petros...
# 792.0                 J     Raihan, A; Said, MNM; Abdullah, SMS; Begum, RA
# 405.0                 J  Wen, Y; Zang, HD; Freeman, B; Ma, QX; Chadwick...
# 1396.0                J        Dhanda, S; Yadav, A; Yadav, DB; Chauhan, BS
# ...                 ...                                                ...
# 1758.0                J  Carter, MS; Hauggaard-Nielsen, H; Heiske, S; J...
# 82.0                  J               Huang, JX; Chen, YQ; Sui, P; Gao, WS
# 526.0                 J                                         Everest, B
# 1795.0                J                Gancone, A; Pubule, J; Blumberga, D
# 1179.0                J  Tian, Z; Niu, YL; Fan, DL; Sun, LX; Ficsher, G...
#
#                                             Article Title  \
# 232.0   Does carbon farming provide a cost-effective o...
# 1761.0  Influence of Organic and Mineral Fertilizers o...
# 792.0   Climate Change Mitigation Options in the Fores...
# 405.0   Rye cover crop incorporation and high watertab...
# 1396.0  Emerging Issues and Potential Opportunities in...
# ...                                                   ...
# 1758.0  Consequences of field N2O emissions for the en...
# 82.0    Estimation of net greenhouse gas balance using...
# 526.0   Farmers' adaptation to climate-smart agricultu...
# 1795.0  Valorization Methodology for Agriculture Secto...
# 1179.0  Maintaining rice production while mitigating m...
#
#                                             Abstract (AB)  Publication Year  \
# 232.0   In this study, we apply a whole farm bioeconom...            2019.0
# 1761.0  The intensive use of mineral (M) fertilizers m...            2022.0
# 792.0   The Intergovernmental Panel on Climate Change ...            2018.0
# 405.0   Drainage and cultivation of peat soils almost ...            2019.0
# 1396.0  The rice-wheat cropping system (RWCS) is the b...            2022.0
# ...                                                   ...               ...
# 1758.0  One way of reducing the emissions of fossil fu...            2012.0
# 82.0    The net greenhouse gas balance (NGHGB), estima...            2013.0
# 526.0   Some of the measures to be taken to reduce gre...            2021.0
# 1795.0  Agriculture sector holds an essential role in ...            2021.0
# 1179.0  China is the largest rice producing and consum...            2018.0
#
#                                      DOI Researcher1 Researcher2 Researcher3  \
# 232.0            10.1111/1467-8489.12306     INCLUDE         NaN     INCLUDE
# 1761.0       10.3390/agriculture12040464     INCLUDE         NaN     INCLUDE
# 792.0      10.17576/jkukm-2018-si1(6)-11     EXCLUDE         NaN     EXCLUDE
# 405.0                   10.1002/ldr.3390         NaN     INCLUDE     INCLUDE
# 1396.0          10.3389/fpls.2022.832683         NaN     EXCLUDE     EXCLUDE
# ...                                  ...         ...         ...         ...
# 1758.0  10.1111/j.1757-1707.2011.01132.x     INCLUDE         NaN     INCLUDE
# 82.0     10.1016/j.scitotenv.2013.03.035     INCLUDE     INCLUDE         NaN
# 526.0         10.1007/s10668-020-00767-1         NaN     INCLUDE     INCLUDE
# 1795.0          10.2478/rtuect-2021-0071     EXCLUDE         NaN     EXCLUDE
# 1179.0        10.1016/j.agsy.2017.04.006     EXCLUDE     INCLUDE     EXCLUDE
#
#        Final decision Review studies Duplicates chatgpt
# 232.0         INCLUDE            NaN        NaN     Yes
# 1761.0        INCLUDE         Review        NaN    Yes.
# 792.0         EXCLUDE            NaN        NaN     Yes
# 405.0         INCLUDE            NaN        NaN     Yes
# 1396.0        EXCLUDE            NaN        NaN    Yes.
# ...               ...            ...        ...     ...
# 1758.0        INCLUDE            NaN        NaN     Yes
# 82.0          INCLUDE            NaN        NaN    Yes.
# 526.0         INCLUDE            NaN        NaN    Yes.
# 1795.0        EXCLUDE            NaN        NaN     No.
# 1179.0        EXCLUDE            NaN        NaN     Yes
#
# [100 rows x 13 columns]

# %%
train_b1.to_excel("chatgpt_responses_b1.xlsx")

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(train_b1["Final decision"] == "INCLUDE", train_b1["chatgpt"].apply(lambda x: int("Yes" in x)), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#        False     0.7778    0.2545    0.3836        55
#         True     0.5000    0.9111    0.6457        45
#
#     accuracy                         0.5500       100
#    macro avg     0.6389    0.5828    0.5146       100
# weighted avg     0.6528    0.5500    0.5015       100

# %%
# %%time
b = "Does the article cover climate change mitigation?"
b = b.replace("article", "abstract")
responses = []
for i, ix in enumerate(chatgpt_train_sample.index):
    t, a, label = chatgpt_train_sample.loc[ix]["Article Title  Abstract (AB)  Final decision".split("  ")]
    a = a.replace("\n", " ")
    a = " ".join(a.split(" ")).strip()
    o = chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
    o = o.replace("\n", " ").strip()
    responses.append([ix, o])
    print(100*(i+1)/chatgpt_train_sample.shape[0], ix, o, label)
# Out:
# 1.0 232.0 Yes INCLUDE
# 2.0 1761.0 Yes. INCLUDE
# 3.0 792.0 Yes EXCLUDE
# 4.0 405.0 Yes. INCLUDE
# 5.0 1396.0 Yes. EXCLUDE
# 6.0 433.0 Yes. EXCLUDE
# 7.0 543.0 Yes EXCLUDE
# 8.0 412.0 Yes INCLUDE
# 9.0 1397.0 Yes. EXCLUDE
# 10.0 688.0 Yes INCLUDE
# 11.0 743.0 Yes EXCLUDE
# 12.0 1222.0 Yes. EXCLUDE
# 13.0 329.0 Yes EXCLUDE
# 14.0 1365.0 Yes. EXCLUDE
# 15.0 677.0 Yes INCLUDE
# 16.0 1432.0 Yes. INCLUDE
# 17.0 507.0 Yes. EXCLUDE
# 18.0 1302.0 Yes EXCLUDE
# 19.0 847.0 Yes INCLUDE
# 20.0 1580.0 Yes EXCLUDE
# Thinking...
# 21.0 1700.0 Yes. EXCLUDE
# 22.0 920.0 Yes. INCLUDE
# 23.0 987.0 Yes INCLUDE
# 24.0 1673.0 Yes. INCLUDE
# 25.0 312.0 Yes INCLUDE
# 26.0 444.0 Yes. EXCLUDE
# 27.0 1171.0 Yes. INCLUDE
# 28.0 1448.0 Yes EXCLUDE
# 29.0 1808.0 Yes EXCLUDE
# 30.0 734.0 Yes INCLUDE
# 31.0 430.0 Yes INCLUDE
# 32.0 423.0 Yes INCLUDE
# 33.0 718.0 Yes. EXCLUDE
# 34.0 828.0 Yes. EXCLUDE
# 35.0 124.0 Yes EXCLUDE
# 36.0 1088.0 Yes EXCLUDE
# 37.0 1172.0 Yes. EXCLUDE
# 38.0 38.0 Yes INCLUDE
# 39.0 355.0 Yes. EXCLUDE
# 40.0 1460.0 Yes. EXCLUDE
# 41.0 930.0 Yes EXCLUDE
# 42.0 574.0 Yes. EXCLUDE
# 43.0 168.0 Yes INCLUDE
# 44.0 362.0 Yes INCLUDE
# 45.0 1136.0 Yes. INCLUDE
# 46.0 502.0 Yes EXCLUDE
# 47.0 169.0 Yes EXCLUDE
# 48.0 1979.0 Yes INCLUDE
# 49.0 324.0 Yes. INCLUDE
# 50.0 1546.0 Yes INCLUDE
# 51.0 1099.0 Yes. INCLUDE
# 52.0 1187.0 Yes. EXCLUDE
# 53.0 892.0 Yes EXCLUDE
# 54.0 691.0 Yes. EXCLUDE
# 55.0 1380.0 Yes EXCLUDE
# 56.0 1841.0 Yes INCLUDE
# 57.0 177.0 Yes. INCLUDE
# 58.0 1563.0 Yes INCLUDE
# 59.0 1893.0 Yes. EXCLUDE
# 60.0 254.0 Yes EXCLUDE
# 61.0 34.0 Yes. EXCLUDE
# 62.0 325.0 Yes. EXCLUDE
# 63.0 222.0 Yes EXCLUDE
# 64.0 1671.0 Yes INCLUDE
# 65.0 114.0 Yes EXCLUDE
# 66.0 126.0 Yes. EXCLUDE
# 67.0 215.0 Yes INCLUDE
# 68.0 785.0 Yes EXCLUDE
# 69.0 894.0 Yes. INCLUDE
# 70.0 1793.0 Yes. INCLUDE
# 71.0 316.0 Yes EXCLUDE
# 72.0 1727.0 Yes INCLUDE
# 73.0 320.0 Yes. EXCLUDE
# 74.0 204.0 Yes EXCLUDE
# 75.0 565.0 Yes INCLUDE
# 76.0 1665.0 No. EXCLUDE
# 77.0 144.0 Yes INCLUDE
# 78.0 343.0 Yes. INCLUDE
# 79.0 1748.0 Yes EXCLUDE
# 80.0 1619.0 Yes INCLUDE
# 81.0 1057.0 Yes EXCLUDE
# 82.0 890.0 Yes EXCLUDE
# 83.0 1659.0 Yes EXCLUDE
# 84.0 1543.0 Yes EXCLUDE
# 85.0 1216.0 Yes. EXCLUDE
# 86.0 616.0 Yes EXCLUDE
# 87.0 1314.0 Yes INCLUDE
# 88.0 510.0 Yes INCLUDE
# 89.0 73.0 Yes EXCLUDE
# 90.0 1245.0 Yes. INCLUDE
# 91.0 1871.0 Yes. INCLUDE
# 92.0 1472.0 Yes EXCLUDE
# 93.0 371.0 Yes INCLUDE
# 94.0 604.0 Yes INCLUDE
# 95.0 889.0 Yes EXCLUDE
# 96.0 1758.0 Yes. INCLUDE
# 97.0 82.0 Yes INCLUDE
# 98.0 526.0 Yes INCLUDE
# 99.0 1795.0 Yes EXCLUDE
# 100.0 1179.0 Yes EXCLUDE
# Wall time: 2min 47s

# %%
train_b2 = chatgpt_train_sample.copy()
train_b2["chatgpt"] = [x[1] for x in responses]
train_b2
# Out:
#        Publication Type                                            Authors  \
# 232.0                 J                   Tang, K; He, CT; Ma, CB; Wang, D
# 1761.0                J  Allam, M; Radicetti, E; Quintarelli, V; Petros...
# 792.0                 J     Raihan, A; Said, MNM; Abdullah, SMS; Begum, RA
# 405.0                 J  Wen, Y; Zang, HD; Freeman, B; Ma, QX; Chadwick...
# 1396.0                J        Dhanda, S; Yadav, A; Yadav, DB; Chauhan, BS
# ...                 ...                                                ...
# 1758.0                J  Carter, MS; Hauggaard-Nielsen, H; Heiske, S; J...
# 82.0                  J               Huang, JX; Chen, YQ; Sui, P; Gao, WS
# 526.0                 J                                         Everest, B
# 1795.0                J                Gancone, A; Pubule, J; Blumberga, D
# 1179.0                J  Tian, Z; Niu, YL; Fan, DL; Sun, LX; Ficsher, G...
#
#                                             Article Title  \
# 232.0   Does carbon farming provide a cost-effective o...
# 1761.0  Influence of Organic and Mineral Fertilizers o...
# 792.0   Climate Change Mitigation Options in the Fores...
# 405.0   Rye cover crop incorporation and high watertab...
# 1396.0  Emerging Issues and Potential Opportunities in...
# ...                                                   ...
# 1758.0  Consequences of field N2O emissions for the en...
# 82.0    Estimation of net greenhouse gas balance using...
# 526.0   Farmers' adaptation to climate-smart agricultu...
# 1795.0  Valorization Methodology for Agriculture Secto...
# 1179.0  Maintaining rice production while mitigating m...
#
#                                             Abstract (AB)  Publication Year  \
# 232.0   In this study, we apply a whole farm bioeconom...            2019.0
# 1761.0  The intensive use of mineral (M) fertilizers m...            2022.0
# 792.0   The Intergovernmental Panel on Climate Change ...            2018.0
# 405.0   Drainage and cultivation of peat soils almost ...            2019.0
# 1396.0  The rice-wheat cropping system (RWCS) is the b...            2022.0
# ...                                                   ...               ...
# 1758.0  One way of reducing the emissions of fossil fu...            2012.0
# 82.0    The net greenhouse gas balance (NGHGB), estima...            2013.0
# 526.0   Some of the measures to be taken to reduce gre...            2021.0
# 1795.0  Agriculture sector holds an essential role in ...            2021.0
# 1179.0  China is the largest rice producing and consum...            2018.0
#
#                                      DOI Researcher1 Researcher2 Researcher3  \
# 232.0            10.1111/1467-8489.12306     INCLUDE         NaN     INCLUDE
# 1761.0       10.3390/agriculture12040464     INCLUDE         NaN     INCLUDE
# 792.0      10.17576/jkukm-2018-si1(6)-11     EXCLUDE         NaN     EXCLUDE
# 405.0                   10.1002/ldr.3390         NaN     INCLUDE     INCLUDE
# 1396.0          10.3389/fpls.2022.832683         NaN     EXCLUDE     EXCLUDE
# ...                                  ...         ...         ...         ...
# 1758.0  10.1111/j.1757-1707.2011.01132.x     INCLUDE         NaN     INCLUDE
# 82.0     10.1016/j.scitotenv.2013.03.035     INCLUDE     INCLUDE         NaN
# 526.0         10.1007/s10668-020-00767-1         NaN     INCLUDE     INCLUDE
# 1795.0          10.2478/rtuect-2021-0071     EXCLUDE         NaN     EXCLUDE
# 1179.0        10.1016/j.agsy.2017.04.006     EXCLUDE     INCLUDE     EXCLUDE
#
#        Final decision Review studies Duplicates chatgpt
# 232.0         INCLUDE            NaN        NaN     Yes
# 1761.0        INCLUDE         Review        NaN    Yes.
# 792.0         EXCLUDE            NaN        NaN     Yes
# 405.0         INCLUDE            NaN        NaN    Yes.
# 1396.0        EXCLUDE            NaN        NaN    Yes.
# ...               ...            ...        ...     ...
# 1758.0        INCLUDE            NaN        NaN    Yes.
# 82.0          INCLUDE            NaN        NaN     Yes
# 526.0         INCLUDE            NaN        NaN     Yes
# 1795.0        EXCLUDE            NaN        NaN     Yes
# 1179.0        EXCLUDE            NaN        NaN     Yes
#
# [100 rows x 13 columns]

# %%
train_b2.to_excel("chatgpt_responses_b2.xlsx")

# %%
print(classification_report(train_b2["Final decision"] == "INCLUDE", train_b2["chatgpt"].apply(lambda x: int("Yes" in x)), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#        False     1.0000    0.0182    0.0357        55
#         True     0.4545    1.0000    0.6250        45
#
#     accuracy                         0.4600       100
#    macro avg     0.7273    0.5091    0.3304       100
# weighted avg     0.7545    0.4600    0.3009       100

# %%
# %%time
b = "Does the article cover climate change adaptation?"
b = b.replace("article", "abstract")
responses = []
for i, ix in enumerate(chatgpt_train_sample.index):
    t, a, label = chatgpt_train_sample.loc[ix]["Article Title  Abstract (AB)  Final decision".split("  ")]
    a = a.replace("\n", " ")
    a = " ".join(a.split(" ")).strip()
    o = chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
    o = o.replace("\n", " ").strip()
    responses.append([ix, o])
    print(100*(i+1)/chatgpt_train_sample.shape[0], ix, o, label)
# Out:
# 1.0 232.0 Yes. INCLUDE
# 2.0 1761.0 No. INCLUDE
# 3.0 792.0 No. EXCLUDE
# 4.0 405.0 Yes INCLUDE
# 5.0 1396.0 Yes EXCLUDE
# 6.0 433.0 Yes EXCLUDE
# 7.0 543.0 No. EXCLUDE
# 8.0 412.0 Yes. INCLUDE
# 9.0 1397.0 Yes EXCLUDE
# 10.0 688.0 Yes INCLUDE
# 11.0 743.0 Yes EXCLUDE
# 12.0 1222.0 Yes EXCLUDE
# 13.0 329.0 Yes. EXCLUDE
# 14.0 1365.0 Yes. EXCLUDE
# 15.0 677.0 No INCLUDE
# 16.0 1432.0 Yes INCLUDE
# 17.0 507.0 Yes. EXCLUDE
# 18.0 1302.0 Yes EXCLUDE
# 19.0 847.0 Yes INCLUDE
# 20.0 1580.0 Yes EXCLUDE
# 21.0 1700.0 Yes. EXCLUDE
# 22.0 920.0 Yes. INCLUDE
# 23.0 987.0 Yes INCLUDE
# 24.0 1673.0 No. INCLUDE
# 25.0 312.0 Yes INCLUDE
# 26.0 444.0 Yes EXCLUDE
# 27.0 1171.0 Yes INCLUDE
# 28.0 1448.0 Yes EXCLUDE
# 29.0 1808.0 Yes EXCLUDE
# 30.0 734.0 Yes INCLUDE
# 31.0 430.0 Yes INCLUDE
# 32.0 423.0 No INCLUDE
# 33.0 718.0 Yes. EXCLUDE
# 34.0 828.0 Yes. EXCLUDE
# 35.0 124.0 Yes. EXCLUDE
# 36.0 1088.0 Yes EXCLUDE
# 37.0 1172.0 Yes. EXCLUDE
# 38.0 38.0 Yes. INCLUDE
# 39.0 355.0 No. EXCLUDE
# 40.0 1460.0 No. The abstract does EXCLUDE
# 41.0 930.0 Yes EXCLUDE
# 42.0 574.0 Yes. EXCLUDE
# 43.0 168.0 Yes INCLUDE
# 44.0 362.0 No. INCLUDE
# 45.0 1136.0 Yes. INCLUDE
# 46.0 502.0 Yes EXCLUDE
# 47.0 169.0 Yes EXCLUDE
# 48.0 1979.0 Yes INCLUDE
# 49.0 324.0 Yes INCLUDE
# 50.0 1546.0 No. INCLUDE
# 51.0 1099.0 Yes INCLUDE
# 52.0 1187.0 Yes EXCLUDE
# 53.0 892.0 Yes EXCLUDE
# 54.0 691.0 No. EXCLUDE
# 55.0 1380.0 Yes EXCLUDE
# 56.0 1841.0 No. INCLUDE
# 57.0 177.0 Yes. INCLUDE
# 58.0 1563.0 Yes INCLUDE
# 59.0 1893.0 No. The abstract specifically EXCLUDE
# 60.0 254.0 No. The abstract describes EXCLUDE
# 61.0 34.0 Yes EXCLUDE
# 62.0 325.0 Yes EXCLUDE
# 63.0 222.0 Yes EXCLUDE
# 64.0 1671.0 Yes. INCLUDE
# 65.0 114.0 No. EXCLUDE
# 66.0 126.0 Yes EXCLUDE
# 67.0 215.0 Yes INCLUDE
# 68.0 785.0 Yes EXCLUDE
# 69.0 894.0 Yes INCLUDE
# 70.0 1793.0 Yes INCLUDE
# 71.0 316.0 No. EXCLUDE
# 72.0 1727.0 Yes. INCLUDE
# 73.0 320.0 No. EXCLUDE
# 74.0 204.0 Yes EXCLUDE
# 75.0 565.0 Yes INCLUDE
# 76.0 1665.0 No. EXCLUDE
# 77.0 144.0 Yes. INCLUDE
# 78.0 343.0 Yes INCLUDE
# 79.0 1748.0 Yes. EXCLUDE
# 80.0 1619.0 Yes. INCLUDE
# 81.0 1057.0 Yes EXCLUDE
# 82.0 890.0 Yes. EXCLUDE
# 83.0 1659.0 Yes. EXCLUDE
# 84.0 1543.0 Yes, the abstract covers EXCLUDE
# 85.0 1216.0 Yes. EXCLUDE
# 86.0 616.0 No EXCLUDE
# 87.0 1314.0 Yes INCLUDE
# 88.0 510.0 Yes. INCLUDE
# 89.0 73.0 No. EXCLUDE
# 90.0 1245.0 Yes. INCLUDE
# 91.0 1871.0 No. INCLUDE
# 92.0 1472.0 No EXCLUDE
# 93.0 371.0 Yes INCLUDE
# 94.0 604.0 Yes INCLUDE
# 95.0 889.0 Yes EXCLUDE
# 96.0 1758.0 No INCLUDE
# 97.0 82.0 Yes INCLUDE
# 98.0 526.0 Yes INCLUDE
# 99.0 1795.0 No. The abstract only EXCLUDE
# 100.0 1179.0 Yes EXCLUDE
# Wall time: 2min 11s

# %%
train_b3 = chatgpt_train_sample.copy()
train_b3["chatgpt"] = [x[1] for x in responses]
train_b3
# Out:
#        Publication Type                                            Authors  \
# 232.0                 J                   Tang, K; He, CT; Ma, CB; Wang, D
# 1761.0                J  Allam, M; Radicetti, E; Quintarelli, V; Petros...
# 792.0                 J     Raihan, A; Said, MNM; Abdullah, SMS; Begum, RA
# 405.0                 J  Wen, Y; Zang, HD; Freeman, B; Ma, QX; Chadwick...
# 1396.0                J        Dhanda, S; Yadav, A; Yadav, DB; Chauhan, BS
# ...                 ...                                                ...
# 1758.0                J  Carter, MS; Hauggaard-Nielsen, H; Heiske, S; J...
# 82.0                  J               Huang, JX; Chen, YQ; Sui, P; Gao, WS
# 526.0                 J                                         Everest, B
# 1795.0                J                Gancone, A; Pubule, J; Blumberga, D
# 1179.0                J  Tian, Z; Niu, YL; Fan, DL; Sun, LX; Ficsher, G...
#
#                                             Article Title  \
# 232.0   Does carbon farming provide a cost-effective o...
# 1761.0  Influence of Organic and Mineral Fertilizers o...
# 792.0   Climate Change Mitigation Options in the Fores...
# 405.0   Rye cover crop incorporation and high watertab...
# 1396.0  Emerging Issues and Potential Opportunities in...
# ...                                                   ...
# 1758.0  Consequences of field N2O emissions for the en...
# 82.0    Estimation of net greenhouse gas balance using...
# 526.0   Farmers' adaptation to climate-smart agricultu...
# 1795.0  Valorization Methodology for Agriculture Secto...
# 1179.0  Maintaining rice production while mitigating m...
#
#                                             Abstract (AB)  Publication Year  \
# 232.0   In this study, we apply a whole farm bioeconom...            2019.0
# 1761.0  The intensive use of mineral (M) fertilizers m...            2022.0
# 792.0   The Intergovernmental Panel on Climate Change ...            2018.0
# 405.0   Drainage and cultivation of peat soils almost ...            2019.0
# 1396.0  The rice-wheat cropping system (RWCS) is the b...            2022.0
# ...                                                   ...               ...
# 1758.0  One way of reducing the emissions of fossil fu...            2012.0
# 82.0    The net greenhouse gas balance (NGHGB), estima...            2013.0
# 526.0   Some of the measures to be taken to reduce gre...            2021.0
# 1795.0  Agriculture sector holds an essential role in ...            2021.0
# 1179.0  China is the largest rice producing and consum...            2018.0
#
#                                      DOI Researcher1 Researcher2 Researcher3  \
# 232.0            10.1111/1467-8489.12306     INCLUDE         NaN     INCLUDE
# 1761.0       10.3390/agriculture12040464     INCLUDE         NaN     INCLUDE
# 792.0      10.17576/jkukm-2018-si1(6)-11     EXCLUDE         NaN     EXCLUDE
# 405.0                   10.1002/ldr.3390         NaN     INCLUDE     INCLUDE
# 1396.0          10.3389/fpls.2022.832683         NaN     EXCLUDE     EXCLUDE
# ...                                  ...         ...         ...         ...
# 1758.0  10.1111/j.1757-1707.2011.01132.x     INCLUDE         NaN     INCLUDE
# 82.0     10.1016/j.scitotenv.2013.03.035     INCLUDE     INCLUDE         NaN
# 526.0         10.1007/s10668-020-00767-1         NaN     INCLUDE     INCLUDE
# 1795.0          10.2478/rtuect-2021-0071     EXCLUDE         NaN     EXCLUDE
# 1179.0        10.1016/j.agsy.2017.04.006     EXCLUDE     INCLUDE     EXCLUDE
#
#        Final decision Review studies Duplicates                chatgpt
# 232.0         INCLUDE            NaN        NaN                   Yes.
# 1761.0        INCLUDE         Review        NaN                    No.
# 792.0         EXCLUDE            NaN        NaN                    No.
# 405.0         INCLUDE            NaN        NaN                    Yes
# 1396.0        EXCLUDE            NaN        NaN                    Yes
# ...               ...            ...        ...                    ...
# 1758.0        INCLUDE            NaN        NaN                     No
# 82.0          INCLUDE            NaN        NaN                    Yes
# 526.0         INCLUDE            NaN        NaN                    Yes
# 1795.0        EXCLUDE            NaN        NaN  No. The abstract only
# 1179.0        EXCLUDE            NaN        NaN                    Yes
#
# [100 rows x 13 columns]

# %%
train_b3.to_excel("chatgpt_responses_b3.xlsx")

# %%
print(classification_report(train_b3["Final decision"] == "INCLUDE", train_b3["chatgpt"].apply(lambda x: int("Yes" in x)), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#        False     0.6250    0.2727    0.3797        55
#         True     0.4737    0.8000    0.5950        45
#
#     accuracy                         0.5100       100
#    macro avg     0.5493    0.5364    0.4874       100
# weighted avg     0.5569    0.5100    0.4766       100

# %%
# %%time
b = "Does the article comprehensively cover climate change and environmental aspects?"
b = b.replace("article", "abstract")
responses = []
for i, ix in enumerate(chatgpt_train_sample.index):
    t, a, label = chatgpt_train_sample.loc[ix]["Article Title  Abstract (AB)  Final decision".split("  ")]
    a = a.replace("\n", " ")
    a = " ".join(a.split(" ")).strip()
    o = chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
    o = o.replace("\n", " ").strip()
    responses.append([ix, o])
    print(100*(i+1)/chatgpt_train_sample.shape[0], ix, o, label)
# Out:
# 1.0 232.0 Yes. INCLUDE
# 2.0 1761.0 Yes INCLUDE
# 3.0 792.0 Yes EXCLUDE
# 4.0 405.0 Yes INCLUDE
# 5.0 1396.0 Yes. EXCLUDE
# 6.0 433.0 Yes. EXCLUDE
# 7.0 543.0 Yes EXCLUDE
# 8.0 412.0 Yes INCLUDE
# 9.0 1397.0 Yes EXCLUDE
# 10.0 688.0 Yes INCLUDE
# 11.0 743.0 Yes EXCLUDE
# 12.0 1222.0 Yes EXCLUDE
# 13.0 329.0 Yes EXCLUDE
# 14.0 1365.0 Yes. EXCLUDE
# 15.0 677.0 Yes INCLUDE
# 16.0 1432.0 Yes. INCLUDE
# 17.0 507.0 Yes. EXCLUDE
# 18.0 1302.0 Yes EXCLUDE
# 19.0 847.0 Yes. INCLUDE
# 20.0 1580.0 Yes EXCLUDE
# 21.0 1700.0 Yes EXCLUDE
# 22.0 920.0 Yes INCLUDE
# 23.0 987.0 Yes INCLUDE
# 24.0 1673.0 Yes INCLUDE
# 25.0 312.0 Yes INCLUDE
# 26.0 444.0 Yes EXCLUDE
# 27.0 1171.0 Yes. INCLUDE
# 28.0 1448.0 Yes EXCLUDE
# 29.0 1808.0 Yes EXCLUDE
# 30.0 734.0 Yes INCLUDE
# 31.0 430.0 Yes INCLUDE
# 32.0 423.0 Yes INCLUDE
# 33.0 718.0 Yes EXCLUDE
# 34.0 828.0 No. The abstract mentions EXCLUDE
# 35.0 124.0 Yes EXCLUDE
# 36.0 1088.0 Yes EXCLUDE
# 37.0 1172.0 Yes EXCLUDE
# 38.0 38.0 Yes INCLUDE
# 39.0 355.0 Yes EXCLUDE
# 40.0 1460.0 Yes EXCLUDE
# 41.0 930.0 Yes EXCLUDE
# 42.0 574.0 Yes. EXCLUDE
# 43.0 168.0 Yes INCLUDE
# 44.0 362.0 Yes. INCLUDE
# 45.0 1136.0 Yes INCLUDE
# 46.0 502.0 Yes EXCLUDE
# 47.0 169.0 Yes EXCLUDE
# 48.0 1979.0 Yes. INCLUDE
# 49.0 324.0 Yes INCLUDE
# 50.0 1546.0 Yes. INCLUDE
# 51.0 1099.0 Yes INCLUDE
# 52.0 1187.0 Yes EXCLUDE
# 53.0 892.0 Yes EXCLUDE
# 54.0 691.0 Yes EXCLUDE
# 55.0 1380.0 Yes. EXCLUDE
# 56.0 1841.0 Yes INCLUDE
# 57.0 177.0 Yes INCLUDE
# 58.0 1563.0 Yes INCLUDE
# 59.0 1893.0 Yes EXCLUDE
# 60.0 254.0 Yes EXCLUDE
# 61.0 34.0 Yes EXCLUDE
# 62.0 325.0 Yes EXCLUDE
# 63.0 222.0 Yes. EXCLUDE
# 64.0 1671.0 Yes. INCLUDE
# 65.0 114.0 Yes. EXCLUDE
# 66.0 126.0 Yes EXCLUDE
# 67.0 215.0 Yes INCLUDE
# 68.0 785.0 Yes. EXCLUDE
# 69.0 894.0 Yes INCLUDE
# 70.0 1793.0 Yes INCLUDE
# 71.0 316.0 Yes EXCLUDE
# 72.0 1727.0 Yes INCLUDE
# 73.0 320.0 Yes EXCLUDE
# 74.0 204.0 Yes EXCLUDE
# 75.0 565.0 Yes INCLUDE
# 76.0 1665.0 No. EXCLUDE
# 77.0 144.0 Yes INCLUDE
# 78.0 343.0 Yes INCLUDE
# 79.0 1748.0 Yes EXCLUDE
# 80.0 1619.0 Yes INCLUDE
# 81.0 1057.0 Yes EXCLUDE
# 82.0 890.0 Yes EXCLUDE
# 83.0 1659.0 No. The abstract does EXCLUDE
# 84.0 1543.0 Yes. EXCLUDE
# 85.0 1216.0 Yes. EXCLUDE
# 86.0 616.0 Yes. EXCLUDE
# 87.0 1314.0 Yes INCLUDE
# 88.0 510.0 Yes INCLUDE
# 89.0 73.0 Yes EXCLUDE
# 90.0 1245.0 Yes INCLUDE
# 91.0 1871.0 Yes INCLUDE
# 92.0 1472.0 Yes EXCLUDE
# 93.0 371.0 Yes INCLUDE
# 94.0 604.0 Yes INCLUDE
# 95.0 889.0 Yes EXCLUDE
# 96.0 1758.0 Yes INCLUDE
# 97.0 82.0 Yes INCLUDE
# 98.0 526.0 Yes. INCLUDE
# 99.0 1795.0 Yes EXCLUDE
# 100.0 1179.0 Yes. EXCLUDE
# Wall time: 2min 12s

# %%
train_b4 = chatgpt_train_sample.copy()
train_b4["chatgpt"] = [x[1] for x in responses]
train_b4
# Out:
#        Publication Type                                            Authors  \
# 232.0                 J                   Tang, K; He, CT; Ma, CB; Wang, D
# 1761.0                J  Allam, M; Radicetti, E; Quintarelli, V; Petros...
# 792.0                 J     Raihan, A; Said, MNM; Abdullah, SMS; Begum, RA
# 405.0                 J  Wen, Y; Zang, HD; Freeman, B; Ma, QX; Chadwick...
# 1396.0                J        Dhanda, S; Yadav, A; Yadav, DB; Chauhan, BS
# ...                 ...                                                ...
# 1758.0                J  Carter, MS; Hauggaard-Nielsen, H; Heiske, S; J...
# 82.0                  J               Huang, JX; Chen, YQ; Sui, P; Gao, WS
# 526.0                 J                                         Everest, B
# 1795.0                J                Gancone, A; Pubule, J; Blumberga, D
# 1179.0                J  Tian, Z; Niu, YL; Fan, DL; Sun, LX; Ficsher, G...
#
#                                             Article Title  \
# 232.0   Does carbon farming provide a cost-effective o...
# 1761.0  Influence of Organic and Mineral Fertilizers o...
# 792.0   Climate Change Mitigation Options in the Fores...
# 405.0   Rye cover crop incorporation and high watertab...
# 1396.0  Emerging Issues and Potential Opportunities in...
# ...                                                   ...
# 1758.0  Consequences of field N2O emissions for the en...
# 82.0    Estimation of net greenhouse gas balance using...
# 526.0   Farmers' adaptation to climate-smart agricultu...
# 1795.0  Valorization Methodology for Agriculture Secto...
# 1179.0  Maintaining rice production while mitigating m...
#
#                                             Abstract (AB)  Publication Year  \
# 232.0   In this study, we apply a whole farm bioeconom...            2019.0
# 1761.0  The intensive use of mineral (M) fertilizers m...            2022.0
# 792.0   The Intergovernmental Panel on Climate Change ...            2018.0
# 405.0   Drainage and cultivation of peat soils almost ...            2019.0
# 1396.0  The rice-wheat cropping system (RWCS) is the b...            2022.0
# ...                                                   ...               ...
# 1758.0  One way of reducing the emissions of fossil fu...            2012.0
# 82.0    The net greenhouse gas balance (NGHGB), estima...            2013.0
# 526.0   Some of the measures to be taken to reduce gre...            2021.0
# 1795.0  Agriculture sector holds an essential role in ...            2021.0
# 1179.0  China is the largest rice producing and consum...            2018.0
#
#                                      DOI Researcher1 Researcher2 Researcher3  \
# 232.0            10.1111/1467-8489.12306     INCLUDE         NaN     INCLUDE
# 1761.0       10.3390/agriculture12040464     INCLUDE         NaN     INCLUDE
# 792.0      10.17576/jkukm-2018-si1(6)-11     EXCLUDE         NaN     EXCLUDE
# 405.0                   10.1002/ldr.3390         NaN     INCLUDE     INCLUDE
# 1396.0          10.3389/fpls.2022.832683         NaN     EXCLUDE     EXCLUDE
# ...                                  ...         ...         ...         ...
# 1758.0  10.1111/j.1757-1707.2011.01132.x     INCLUDE         NaN     INCLUDE
# 82.0     10.1016/j.scitotenv.2013.03.035     INCLUDE     INCLUDE         NaN
# 526.0         10.1007/s10668-020-00767-1         NaN     INCLUDE     INCLUDE
# 1795.0          10.2478/rtuect-2021-0071     EXCLUDE         NaN     EXCLUDE
# 1179.0        10.1016/j.agsy.2017.04.006     EXCLUDE     INCLUDE     EXCLUDE
#
#        Final decision Review studies Duplicates chatgpt
# 232.0         INCLUDE            NaN        NaN    Yes.
# 1761.0        INCLUDE         Review        NaN     Yes
# 792.0         EXCLUDE            NaN        NaN     Yes
# 405.0         INCLUDE            NaN        NaN     Yes
# 1396.0        EXCLUDE            NaN        NaN    Yes.
# ...               ...            ...        ...     ...
# 1758.0        INCLUDE            NaN        NaN     Yes
# 82.0          INCLUDE            NaN        NaN     Yes
# 526.0         INCLUDE            NaN        NaN    Yes.
# 1795.0        EXCLUDE            NaN        NaN     Yes
# 1179.0        EXCLUDE            NaN        NaN    Yes.
#
# [100 rows x 13 columns]

# %%
train_b4.to_excel("chatgpt_responses_b4.xlsx")

# %%
print(classification_report(train_b4["Final decision"] == "INCLUDE", train_b4["chatgpt"].apply(lambda x: int("Yes" in x)), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#        False     1.0000    0.0545    0.1034        55
#         True     0.4639    1.0000    0.6338        45
#
#     accuracy                         0.4800       100
#    macro avg     0.7320    0.5273    0.3686       100
# weighted avg     0.7588    0.4800    0.3421       100

# %%
# %%time
b = "Does the article address greenhouse gas emissions?"
b = b.replace("article", "abstract")
responses = []
for i, ix in enumerate(chatgpt_train_sample.index):
    t, a, label = chatgpt_train_sample.loc[ix]["Article Title  Abstract (AB)  Final decision".split("  ")]
    a = a.replace("\n", " ")
    a = " ".join(a.split(" ")).strip()
    o = chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
    o = o.replace("\n", " ").strip()
    responses.append([ix, o])
    print(100*(i+1)/chatgpt_train_sample.shape[0], ix, o, label)
# Out:
# 1.0 232.0 Yes INCLUDE
# 2.0 1761.0 Yes INCLUDE
# 3.0 792.0 Yes. EXCLUDE
# 4.0 405.0 Yes INCLUDE
# 5.0 1396.0 Yes. EXCLUDE
# 6.0 433.0 Yes. EXCLUDE
# 7.0 543.0 Yes. EXCLUDE
# 8.0 412.0 Yes INCLUDE
# 9.0 1397.0 Yes EXCLUDE
# 10.0 688.0 Yes. INCLUDE
# 11.0 743.0 Yes EXCLUDE
# 12.0 1222.0 Yes EXCLUDE
# 13.0 329.0 Yes EXCLUDE
# Thinking...
# 14.0 1365.0 Yes. EXCLUDE
# 15.0 677.0 Yes INCLUDE
# 16.0 1432.0 Yes. INCLUDE
# 17.0 507.0 Yes EXCLUDE
# 18.0 1302.0 Yes EXCLUDE
# 19.0 847.0 Yes. INCLUDE
# 20.0 1580.0 Yes. EXCLUDE
# 21.0 1700.0 Yes. EXCLUDE
# 22.0 920.0 Yes. INCLUDE
# 23.0 987.0 Yes INCLUDE
# 24.0 1673.0 Yes INCLUDE
# 25.0 312.0 Yes INCLUDE
# 26.0 444.0 Yes EXCLUDE
# 27.0 1171.0 Yes. INCLUDE
# 28.0 1448.0 Yes. EXCLUDE
# 29.0 1808.0 Yes. EXCLUDE
# 30.0 734.0 Yes INCLUDE
# 31.0 430.0 Yes INCLUDE
# 32.0 423.0 Yes. INCLUDE
# 33.0 718.0 Yes. EXCLUDE
# 34.0 828.0 Yes EXCLUDE
# 35.0 124.0 Yes EXCLUDE
# 36.0 1088.0 Yes. EXCLUDE
# 37.0 1172.0 Yes EXCLUDE
# 38.0 38.0 Yes INCLUDE
# 39.0 355.0 Yes. EXCLUDE
# 40.0 1460.0 Yes EXCLUDE
# 41.0 930.0 Yes EXCLUDE
# 42.0 574.0 Yes EXCLUDE
# 43.0 168.0 Yes. INCLUDE
# 44.0 362.0 Yes. INCLUDE
# 45.0 1136.0 Yes. INCLUDE
# 46.0 502.0 Yes EXCLUDE
# 47.0 169.0 Yes EXCLUDE
# 48.0 1979.0 Yes. INCLUDE
# 49.0 324.0 Yes. INCLUDE
# 50.0 1546.0 Yes INCLUDE
# 51.0 1099.0 Yes INCLUDE
# 52.0 1187.0 Yes EXCLUDE
# 53.0 892.0 Yes EXCLUDE
# 54.0 691.0 Yes. EXCLUDE
# 55.0 1380.0 Yes EXCLUDE
# 56.0 1841.0 Yes INCLUDE
# 57.0 177.0 Yes. INCLUDE
# 58.0 1563.0 Yes. INCLUDE
# 59.0 1893.0 Yes. EXCLUDE
# 60.0 254.0 Yes. EXCLUDE
# 61.0 34.0 Yes EXCLUDE
# 62.0 325.0 Yes. EXCLUDE
# 63.0 222.0 Yes EXCLUDE
# 64.0 1671.0 Yes INCLUDE
# 65.0 114.0 Yes. EXCLUDE
# 66.0 126.0 Yes. EXCLUDE
# 67.0 215.0 Yes. INCLUDE
# 68.0 785.0 Yes EXCLUDE
# 69.0 894.0 Yes INCLUDE
# 70.0 1793.0 Yes INCLUDE
# 71.0 316.0 Yes EXCLUDE
# 72.0 1727.0 Yes INCLUDE
# 73.0 320.0 Yes EXCLUDE
# 74.0 204.0 Yes. EXCLUDE
# 75.0 565.0 Yes INCLUDE
# 76.0 1665.0 No. EXCLUDE
# 77.0 144.0 Yes. INCLUDE
# 78.0 343.0 Yes INCLUDE
# 79.0 1748.0 Yes. EXCLUDE
# 80.0 1619.0 Yes. INCLUDE
# 81.0 1057.0 Yes. EXCLUDE
# 82.0 890.0 Yes EXCLUDE
# 83.0 1659.0 Yes EXCLUDE
# 84.0 1543.0 Yes. EXCLUDE
# Thinking...
# 85.0 1216.0 Yes. EXCLUDE
# 86.0 616.0 Yes. EXCLUDE
# 87.0 1314.0 Yes INCLUDE
# 88.0 510.0 Yes. INCLUDE
# 89.0 73.0 Yes. EXCLUDE
# 90.0 1245.0 Yes INCLUDE
# 91.0 1871.0 Yes INCLUDE
# 92.0 1472.0 Yes. EXCLUDE
# 93.0 371.0 Yes INCLUDE
# 94.0 604.0 Yes. INCLUDE
# 95.0 889.0 Yes EXCLUDE
# 96.0 1758.0 Yes INCLUDE
# 97.0 82.0 Yes. INCLUDE
# 98.0 526.0 Yes INCLUDE
# 99.0 1795.0 Yes. EXCLUDE
# 100.0 1179.0 Yes. EXCLUDE
# Wall time: 3min 4s

# %%
train_b5 = chatgpt_train_sample.copy()
train_b5["chatgpt"] = [x[1] for x in responses]
train_b5
# Out:
#        Publication Type                                            Authors  \
# 232.0                 J                   Tang, K; He, CT; Ma, CB; Wang, D
# 1761.0                J  Allam, M; Radicetti, E; Quintarelli, V; Petros...
# 792.0                 J     Raihan, A; Said, MNM; Abdullah, SMS; Begum, RA
# 405.0                 J  Wen, Y; Zang, HD; Freeman, B; Ma, QX; Chadwick...
# 1396.0                J        Dhanda, S; Yadav, A; Yadav, DB; Chauhan, BS
# ...                 ...                                                ...
# 1758.0                J  Carter, MS; Hauggaard-Nielsen, H; Heiske, S; J...
# 82.0                  J               Huang, JX; Chen, YQ; Sui, P; Gao, WS
# 526.0                 J                                         Everest, B
# 1795.0                J                Gancone, A; Pubule, J; Blumberga, D
# 1179.0                J  Tian, Z; Niu, YL; Fan, DL; Sun, LX; Ficsher, G...
#
#                                             Article Title  \
# 232.0   Does carbon farming provide a cost-effective o...
# 1761.0  Influence of Organic and Mineral Fertilizers o...
# 792.0   Climate Change Mitigation Options in the Fores...
# 405.0   Rye cover crop incorporation and high watertab...
# 1396.0  Emerging Issues and Potential Opportunities in...
# ...                                                   ...
# 1758.0  Consequences of field N2O emissions for the en...
# 82.0    Estimation of net greenhouse gas balance using...
# 526.0   Farmers' adaptation to climate-smart agricultu...
# 1795.0  Valorization Methodology for Agriculture Secto...
# 1179.0  Maintaining rice production while mitigating m...
#
#                                             Abstract (AB)  Publication Year  \
# 232.0   In this study, we apply a whole farm bioeconom...            2019.0
# 1761.0  The intensive use of mineral (M) fertilizers m...            2022.0
# 792.0   The Intergovernmental Panel on Climate Change ...            2018.0
# 405.0   Drainage and cultivation of peat soils almost ...            2019.0
# 1396.0  The rice-wheat cropping system (RWCS) is the b...            2022.0
# ...                                                   ...               ...
# 1758.0  One way of reducing the emissions of fossil fu...            2012.0
# 82.0    The net greenhouse gas balance (NGHGB), estima...            2013.0
# 526.0   Some of the measures to be taken to reduce gre...            2021.0
# 1795.0  Agriculture sector holds an essential role in ...            2021.0
# 1179.0  China is the largest rice producing and consum...            2018.0
#
#                                      DOI Researcher1 Researcher2 Researcher3  \
# 232.0            10.1111/1467-8489.12306     INCLUDE         NaN     INCLUDE
# 1761.0       10.3390/agriculture12040464     INCLUDE         NaN     INCLUDE
# 792.0      10.17576/jkukm-2018-si1(6)-11     EXCLUDE         NaN     EXCLUDE
# 405.0                   10.1002/ldr.3390         NaN     INCLUDE     INCLUDE
# 1396.0          10.3389/fpls.2022.832683         NaN     EXCLUDE     EXCLUDE
# ...                                  ...         ...         ...         ...
# 1758.0  10.1111/j.1757-1707.2011.01132.x     INCLUDE         NaN     INCLUDE
# 82.0     10.1016/j.scitotenv.2013.03.035     INCLUDE     INCLUDE         NaN
# 526.0         10.1007/s10668-020-00767-1         NaN     INCLUDE     INCLUDE
# 1795.0          10.2478/rtuect-2021-0071     EXCLUDE         NaN     EXCLUDE
# 1179.0        10.1016/j.agsy.2017.04.006     EXCLUDE     INCLUDE     EXCLUDE
#
#        Final decision Review studies Duplicates chatgpt
# 232.0         INCLUDE            NaN        NaN     Yes
# 1761.0        INCLUDE         Review        NaN     Yes
# 792.0         EXCLUDE            NaN        NaN    Yes.
# 405.0         INCLUDE            NaN        NaN     Yes
# 1396.0        EXCLUDE            NaN        NaN    Yes.
# ...               ...            ...        ...     ...
# 1758.0        INCLUDE            NaN        NaN     Yes
# 82.0          INCLUDE            NaN        NaN    Yes.
# 526.0         INCLUDE            NaN        NaN     Yes
# 1795.0        EXCLUDE            NaN        NaN    Yes.
# 1179.0        EXCLUDE            NaN        NaN    Yes.
#
# [100 rows x 13 columns]

# %%
train_b5.to_excel("chatgpt_responses_b5.xlsx")

# %%
print(classification_report(train_b5["Final decision"] == "INCLUDE", train_b5["chatgpt"].apply(lambda x: int("Yes" in x)), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#        False     1.0000    0.0182    0.0357        55
#         True     0.4545    1.0000    0.6250        45
#
#     accuracy                         0.4600       100
#    macro avg     0.7273    0.5091    0.3304       100
# weighted avg     0.7545    0.4600    0.3009       100

# %%
# %%time
b = "Does the article assess agroecological practices' impact on climate change?"
b = b.replace("article", "abstract")
responses = []
for i, ix in enumerate(chatgpt_train_sample.index):
    t, a, label = chatgpt_train_sample.loc[ix]["Article Title  Abstract (AB)  Final decision".split("  ")]
    a = a.replace("\n", " ")
    a = " ".join(a.split(" ")).strip()
    o = chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
    o = o.replace("\n", " ").strip()
    responses.append([ix, o])
    print(100*(i+1)/chatgpt_train_sample.shape[0], ix, o, label)
# Out:
# 1.0 232.0 Yes INCLUDE
# 2.0 1761.0 Yes INCLUDE
# 3.0 792.0 No. EXCLUDE
# 4.0 405.0 Yes. INCLUDE
# 5.0 1396.0 Yes. EXCLUDE
# 6.0 433.0 No. EXCLUDE
# 7.0 543.0 No. EXCLUDE
# 8.0 412.0 Yes INCLUDE
# 9.0 1397.0 Yes. EXCLUDE
# 10.0 688.0 Yes. INCLUDE
# 11.0 743.0 Yes. EXCLUDE
# 12.0 1222.0 Yes. EXCLUDE
# 13.0 329.0 Yes. The abstract discusses EXCLUDE
# 14.0 1365.0 Yes. EXCLUDE
# 15.0 677.0 No. INCLUDE
# 16.0 1432.0 Yes INCLUDE
# 17.0 507.0 Yes. The abstract discusses EXCLUDE
# 18.0 1302.0 Yes. EXCLUDE
# 19.0 847.0 Yes INCLUDE
# 20.0 1580.0 Yes. The abstract discusses EXCLUDE
# 21.0 1700.0 Yes. EXCLUDE
# 22.0 920.0 Yes INCLUDE
# 23.0 987.0 Yes INCLUDE
# 24.0 1673.0 Yes. The abstract discusses INCLUDE
# 25.0 312.0 Yes INCLUDE
# 26.0 444.0 Yes. EXCLUDE
# 27.0 1171.0 Yes INCLUDE
# 28.0 1448.0 Yes EXCLUDE
# 29.0 1808.0 Yes EXCLUDE
# 30.0 734.0 Yes. INCLUDE
# 31.0 430.0 Yes INCLUDE
# 32.0 423.0 Yes INCLUDE
# 33.0 718.0 No. EXCLUDE
# 34.0 828.0 No, the abstract does EXCLUDE
# 35.0 124.0 Yes EXCLUDE
# 36.0 1088.0 Yes EXCLUDE
# 37.0 1172.0 Yes EXCLUDE
# 38.0 38.0 Yes. INCLUDE
# 39.0 355.0 Yes EXCLUDE
# 40.0 1460.0 Yes EXCLUDE
# 41.0 930.0 No. The abstract focuses EXCLUDE
# 42.0 574.0 Yes EXCLUDE
# 43.0 168.0 Yes INCLUDE
# 44.0 362.0 Yes INCLUDE
# 45.0 1136.0 Yes INCLUDE
# 46.0 502.0 Yes EXCLUDE
# 47.0 169.0 Yes EXCLUDE
# 48.0 1979.0 Yes. The abstract discusses INCLUDE
# 49.0 324.0 Yes INCLUDE
# 50.0 1546.0 No. INCLUDE
# 51.0 1099.0 Yes INCLUDE
# 52.0 1187.0 Yes EXCLUDE
# 53.0 892.0 No. EXCLUDE
# 54.0 691.0 Yes EXCLUDE
# 55.0 1380.0 Yes EXCLUDE
# 56.0 1841.0 Yes. The abstract assess INCLUDE
# 57.0 177.0 Yes INCLUDE
# 58.0 1563.0 Yes. The abstract assess INCLUDE
# 59.0 1893.0 No. The abstract discusses EXCLUDE
# 60.0 254.0 No. EXCLUDE
# 61.0 34.0 Yes EXCLUDE
# 62.0 325.0 No. EXCLUDE
# 63.0 222.0 Yes. EXCLUDE
# 64.0 1671.0 Yes INCLUDE
# 65.0 114.0 No. EXCLUDE
# 66.0 126.0 No. EXCLUDE
# 67.0 215.0 Yes. INCLUDE
# 68.0 785.0 Yes EXCLUDE
# 69.0 894.0 Yes INCLUDE
# 70.0 1793.0 Yes INCLUDE
# 71.0 316.0 Yes. EXCLUDE
# 72.0 1727.0 Yes. INCLUDE
# 73.0 320.0 Yes EXCLUDE
# 74.0 204.0 Yes EXCLUDE
# 75.0 565.0 Yes. INCLUDE
# 76.0 1665.0 No. EXCLUDE
# 77.0 144.0 Yes INCLUDE
# 78.0 343.0 Yes. INCLUDE
# 79.0 1748.0 Yes EXCLUDE
# 80.0 1619.0 Yes. INCLUDE
# 81.0 1057.0 Yes EXCLUDE
# 82.0 890.0 Yes EXCLUDE
# 83.0 1659.0 No. EXCLUDE
# 84.0 1543.0 Yes. EXCLUDE
# 85.0 1216.0 No. The abstract discusses EXCLUDE
# 86.0 616.0 No EXCLUDE
# 87.0 1314.0 Yes INCLUDE
# 88.0 510.0 Yes INCLUDE
# 89.0 73.0 Yes. EXCLUDE
# 90.0 1245.0 Yes. INCLUDE
# 91.0 1871.0 Yes INCLUDE
# 92.0 1472.0 Yes EXCLUDE
# 93.0 371.0 Yes. INCLUDE
# 94.0 604.0 Yes INCLUDE
# 95.0 889.0 Yes. EXCLUDE
# 96.0 1758.0 Yes INCLUDE
# 97.0 82.0 Yes INCLUDE
# 98.0 526.0 Yes. INCLUDE
# 99.0 1795.0 The abstract does not explicitly EXCLUDE
# 100.0 1179.0 Yes EXCLUDE
# Wall time: 2min 4s

# %%
train_b6 = chatgpt_train_sample.copy()
train_b6["chatgpt"] = [x[1] for x in responses]
train_b6
# Out:
#        Publication Type                                            Authors  \
# 232.0                 J                   Tang, K; He, CT; Ma, CB; Wang, D
# 1761.0                J  Allam, M; Radicetti, E; Quintarelli, V; Petros...
# 792.0                 J     Raihan, A; Said, MNM; Abdullah, SMS; Begum, RA
# 405.0                 J  Wen, Y; Zang, HD; Freeman, B; Ma, QX; Chadwick...
# 1396.0                J        Dhanda, S; Yadav, A; Yadav, DB; Chauhan, BS
# ...                 ...                                                ...
# 1758.0                J  Carter, MS; Hauggaard-Nielsen, H; Heiske, S; J...
# 82.0                  J               Huang, JX; Chen, YQ; Sui, P; Gao, WS
# 526.0                 J                                         Everest, B
# 1795.0                J                Gancone, A; Pubule, J; Blumberga, D
# 1179.0                J  Tian, Z; Niu, YL; Fan, DL; Sun, LX; Ficsher, G...
#
#                                             Article Title  \
# 232.0   Does carbon farming provide a cost-effective o...
# 1761.0  Influence of Organic and Mineral Fertilizers o...
# 792.0   Climate Change Mitigation Options in the Fores...
# 405.0   Rye cover crop incorporation and high watertab...
# 1396.0  Emerging Issues and Potential Opportunities in...
# ...                                                   ...
# 1758.0  Consequences of field N2O emissions for the en...
# 82.0    Estimation of net greenhouse gas balance using...
# 526.0   Farmers' adaptation to climate-smart agricultu...
# 1795.0  Valorization Methodology for Agriculture Secto...
# 1179.0  Maintaining rice production while mitigating m...
#
#                                             Abstract (AB)  Publication Year  \
# 232.0   In this study, we apply a whole farm bioeconom...            2019.0
# 1761.0  The intensive use of mineral (M) fertilizers m...            2022.0
# 792.0   The Intergovernmental Panel on Climate Change ...            2018.0
# 405.0   Drainage and cultivation of peat soils almost ...            2019.0
# 1396.0  The rice-wheat cropping system (RWCS) is the b...            2022.0
# ...                                                   ...               ...
# 1758.0  One way of reducing the emissions of fossil fu...            2012.0
# 82.0    The net greenhouse gas balance (NGHGB), estima...            2013.0
# 526.0   Some of the measures to be taken to reduce gre...            2021.0
# 1795.0  Agriculture sector holds an essential role in ...            2021.0
# 1179.0  China is the largest rice producing and consum...            2018.0
#
#                                      DOI Researcher1 Researcher2 Researcher3  \
# 232.0            10.1111/1467-8489.12306     INCLUDE         NaN     INCLUDE
# 1761.0       10.3390/agriculture12040464     INCLUDE         NaN     INCLUDE
# 792.0      10.17576/jkukm-2018-si1(6)-11     EXCLUDE         NaN     EXCLUDE
# 405.0                   10.1002/ldr.3390         NaN     INCLUDE     INCLUDE
# 1396.0          10.3389/fpls.2022.832683         NaN     EXCLUDE     EXCLUDE
# ...                                  ...         ...         ...         ...
# 1758.0  10.1111/j.1757-1707.2011.01132.x     INCLUDE         NaN     INCLUDE
# 82.0     10.1016/j.scitotenv.2013.03.035     INCLUDE     INCLUDE         NaN
# 526.0         10.1007/s10668-020-00767-1         NaN     INCLUDE     INCLUDE
# 1795.0          10.2478/rtuect-2021-0071     EXCLUDE         NaN     EXCLUDE
# 1179.0        10.1016/j.agsy.2017.04.006     EXCLUDE     INCLUDE     EXCLUDE
#
#        Final decision Review studies Duplicates  \
# 232.0         INCLUDE            NaN        NaN
# 1761.0        INCLUDE         Review        NaN
# 792.0         EXCLUDE            NaN        NaN
# 405.0         INCLUDE            NaN        NaN
# 1396.0        EXCLUDE            NaN        NaN
# ...               ...            ...        ...
# 1758.0        INCLUDE            NaN        NaN
# 82.0          INCLUDE            NaN        NaN
# 526.0         INCLUDE            NaN        NaN
# 1795.0        EXCLUDE            NaN        NaN
# 1179.0        EXCLUDE            NaN        NaN
#
#                                  chatgpt
# 232.0                                Yes
# 1761.0                               Yes
# 792.0                                No.
# 405.0                               Yes.
# 1396.0                              Yes.
# ...                                  ...
# 1758.0                               Yes
# 82.0                                 Yes
# 526.0                               Yes.
# 1795.0  The abstract does not explicitly
# 1179.0                               Yes
#
# [100 rows x 13 columns]

# %%
train_b6.to_excel("chatgpt_responses_b6.xlsx")

# %%
print(classification_report(train_b6["Final decision"] == "INCLUDE", train_b6["chatgpt"].apply(lambda x: int("Yes" in x)), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#        False     0.8947    0.3091    0.4595        55
#         True     0.5309    0.9556    0.6825        45
#
#     accuracy                         0.6000       100
#    macro avg     0.7128    0.6323    0.5710       100
# weighted avg     0.7310    0.6000    0.5598       100

# %%
# %%time
b = "Does the article provide relevance to stakeholders and farmers in the agricultural sector?"
b = b.replace("article", "abstract")
responses = []
for i, ix in enumerate(chatgpt_train_sample.index):
    t, a, label = chatgpt_train_sample.loc[ix]["Article Title  Abstract (AB)  Final decision".split("  ")]
    a = a.replace("\n", " ")
    a = " ".join(a.split(" ")).strip()
    o = chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
    o = o.replace("\n", " ").strip()
    responses.append([ix, o])
    print(100*(i+1)/chatgpt_train_sample.shape[0], ix, o, label)
# Out:
# 1.0 232.0 Yes. The abstract provides INCLUDE
# 2.0 1761.0 Yes INCLUDE
# 3.0 792.0 Yes EXCLUDE
# 4.0 405.0 Yes. The abstract provides INCLUDE
# 5.0 1396.0 Yes EXCLUDE
# 6.0 433.0 Yes EXCLUDE
# 7.0 543.0 Yes EXCLUDE
# 8.0 412.0 Yes INCLUDE
# 9.0 1397.0 Yes EXCLUDE
# 10.0 688.0 Yes. INCLUDE
# 11.0 743.0 Yes EXCLUDE
# 12.0 1222.0 Yes. EXCLUDE
# 13.0 329.0 Yes EXCLUDE
# 14.0 1365.0 Yes. EXCLUDE
# 15.0 677.0 Yes INCLUDE
# 16.0 1432.0 Yes. INCLUDE
# 17.0 507.0 Yes EXCLUDE
# 18.0 1302.0 Yes. EXCLUDE
# 19.0 847.0 Yes INCLUDE
# 20.0 1580.0 Yes. EXCLUDE
# 21.0 1700.0 Yes EXCLUDE
# 22.0 920.0 Yes. The abstract provides INCLUDE
# 23.0 987.0 Yes INCLUDE
# 24.0 1673.0 Yes INCLUDE
# 25.0 312.0 Yes INCLUDE
# 26.0 444.0 Yes EXCLUDE
# 27.0 1171.0 Yes. The abstract provides INCLUDE
# 28.0 1448.0 Yes. The abstract discusses EXCLUDE
# 29.0 1808.0 Yes EXCLUDE
# 30.0 734.0 Yes. INCLUDE
# 31.0 430.0 Yes INCLUDE
# 32.0 423.0 Yes INCLUDE
# 33.0 718.0 Yes EXCLUDE
# 34.0 828.0 Yes. EXCLUDE
# 35.0 124.0 Yes. EXCLUDE
# 36.0 1088.0 Yes EXCLUDE
# 37.0 1172.0 Yes EXCLUDE
# 38.0 38.0 Yes. INCLUDE
# 39.0 355.0 Yes EXCLUDE
# 40.0 1460.0 Yes EXCLUDE
# 41.0 930.0 Yes. The abstract discusses EXCLUDE
# 42.0 574.0 Yes EXCLUDE
# 43.0 168.0 Yes INCLUDE
# 44.0 362.0 Yes INCLUDE
# 45.0 1136.0 Yes. INCLUDE
# 46.0 502.0 Yes EXCLUDE
# 47.0 169.0 Yes EXCLUDE
# 48.0 1979.0 Yes INCLUDE
# 49.0 324.0 Yes INCLUDE
# 50.0 1546.0 Yes INCLUDE
# 51.0 1099.0 Yes INCLUDE
# 52.0 1187.0 Yes EXCLUDE
# 53.0 892.0 Yes EXCLUDE
# 54.0 691.0 Yes EXCLUDE
# 55.0 1380.0 Yes EXCLUDE
# 56.0 1841.0 Yes INCLUDE
# 57.0 177.0 Yes INCLUDE
# 58.0 1563.0 Yes. The abstract provides INCLUDE
# 59.0 1893.0 Yes. EXCLUDE
# 60.0 254.0 Yes. EXCLUDE
# 61.0 34.0 Yes EXCLUDE
# 62.0 325.0 Yes EXCLUDE
# 63.0 222.0 Yes EXCLUDE
# 64.0 1671.0 Yes. INCLUDE
# 65.0 114.0 Yes EXCLUDE
# 66.0 126.0 Yes. EXCLUDE
# 67.0 215.0 Yes INCLUDE
# 68.0 785.0 Yes EXCLUDE
# 69.0 894.0 Yes INCLUDE
# 70.0 1793.0 Yes INCLUDE
# 71.0 316.0 Yes EXCLUDE
# 72.0 1727.0 Yes INCLUDE
# 73.0 320.0 Yes EXCLUDE
# 74.0 204.0 Yes. EXCLUDE
# 75.0 565.0 Yes INCLUDE
# 76.0 1665.0 Yes EXCLUDE
# 77.0 144.0 Yes INCLUDE
# 78.0 343.0 Yes INCLUDE
# 79.0 1748.0 Yes EXCLUDE
# 80.0 1619.0 Yes INCLUDE
# 81.0 1057.0 Yes EXCLUDE
# 82.0 890.0 Yes EXCLUDE
# 83.0 1659.0 Yes EXCLUDE
# 84.0 1543.0 Yes EXCLUDE
# 85.0 1216.0 Yes EXCLUDE
# 86.0 616.0 Yes EXCLUDE
# 87.0 1314.0 Yes INCLUDE
# 88.0 510.0 Yes INCLUDE
# 89.0 73.0 Yes EXCLUDE
# 90.0 1245.0 Yes. The abstract provides INCLUDE
# 91.0 1871.0 Yes INCLUDE
# 92.0 1472.0 Yes. EXCLUDE
# 93.0 371.0 Yes INCLUDE
# 94.0 604.0 Yes INCLUDE
# 95.0 889.0 Yes EXCLUDE
# 96.0 1758.0 Yes INCLUDE
# 97.0 82.0 Yes. INCLUDE
# 98.0 526.0 Yes. INCLUDE
# 99.0 1795.0 Yes EXCLUDE
# 100.0 1179.0 Yes EXCLUDE
# Wall time: 2min 1s

# %%
train_b7 = chatgpt_train_sample.copy()
train_b7["chatgpt"] = [x[1] for x in responses]
train_b7
# Out:
#        Publication Type                                            Authors  \
# 232.0                 J                   Tang, K; He, CT; Ma, CB; Wang, D
# 1761.0                J  Allam, M; Radicetti, E; Quintarelli, V; Petros...
# 792.0                 J     Raihan, A; Said, MNM; Abdullah, SMS; Begum, RA
# 405.0                 J  Wen, Y; Zang, HD; Freeman, B; Ma, QX; Chadwick...
# 1396.0                J        Dhanda, S; Yadav, A; Yadav, DB; Chauhan, BS
# ...                 ...                                                ...
# 1758.0                J  Carter, MS; Hauggaard-Nielsen, H; Heiske, S; J...
# 82.0                  J               Huang, JX; Chen, YQ; Sui, P; Gao, WS
# 526.0                 J                                         Everest, B
# 1795.0                J                Gancone, A; Pubule, J; Blumberga, D
# 1179.0                J  Tian, Z; Niu, YL; Fan, DL; Sun, LX; Ficsher, G...
#
#                                             Article Title  \
# 232.0   Does carbon farming provide a cost-effective o...
# 1761.0  Influence of Organic and Mineral Fertilizers o...
# 792.0   Climate Change Mitigation Options in the Fores...
# 405.0   Rye cover crop incorporation and high watertab...
# 1396.0  Emerging Issues and Potential Opportunities in...
# ...                                                   ...
# 1758.0  Consequences of field N2O emissions for the en...
# 82.0    Estimation of net greenhouse gas balance using...
# 526.0   Farmers' adaptation to climate-smart agricultu...
# 1795.0  Valorization Methodology for Agriculture Secto...
# 1179.0  Maintaining rice production while mitigating m...
#
#                                             Abstract (AB)  Publication Year  \
# 232.0   In this study, we apply a whole farm bioeconom...            2019.0
# 1761.0  The intensive use of mineral (M) fertilizers m...            2022.0
# 792.0   The Intergovernmental Panel on Climate Change ...            2018.0
# 405.0   Drainage and cultivation of peat soils almost ...            2019.0
# 1396.0  The rice-wheat cropping system (RWCS) is the b...            2022.0
# ...                                                   ...               ...
# 1758.0  One way of reducing the emissions of fossil fu...            2012.0
# 82.0    The net greenhouse gas balance (NGHGB), estima...            2013.0
# 526.0   Some of the measures to be taken to reduce gre...            2021.0
# 1795.0  Agriculture sector holds an essential role in ...            2021.0
# 1179.0  China is the largest rice producing and consum...            2018.0
#
#                                      DOI Researcher1 Researcher2 Researcher3  \
# 232.0            10.1111/1467-8489.12306     INCLUDE         NaN     INCLUDE
# 1761.0       10.3390/agriculture12040464     INCLUDE         NaN     INCLUDE
# 792.0      10.17576/jkukm-2018-si1(6)-11     EXCLUDE         NaN     EXCLUDE
# 405.0                   10.1002/ldr.3390         NaN     INCLUDE     INCLUDE
# 1396.0          10.3389/fpls.2022.832683         NaN     EXCLUDE     EXCLUDE
# ...                                  ...         ...         ...         ...
# 1758.0  10.1111/j.1757-1707.2011.01132.x     INCLUDE         NaN     INCLUDE
# 82.0     10.1016/j.scitotenv.2013.03.035     INCLUDE     INCLUDE         NaN
# 526.0         10.1007/s10668-020-00767-1         NaN     INCLUDE     INCLUDE
# 1795.0          10.2478/rtuect-2021-0071     EXCLUDE         NaN     EXCLUDE
# 1179.0        10.1016/j.agsy.2017.04.006     EXCLUDE     INCLUDE     EXCLUDE
#
#        Final decision Review studies Duplicates                     chatgpt
# 232.0         INCLUDE            NaN        NaN  Yes. The abstract provides
# 1761.0        INCLUDE         Review        NaN                         Yes
# 792.0         EXCLUDE            NaN        NaN                         Yes
# 405.0         INCLUDE            NaN        NaN  Yes. The abstract provides
# 1396.0        EXCLUDE            NaN        NaN                         Yes
# ...               ...            ...        ...                         ...
# 1758.0        INCLUDE            NaN        NaN                         Yes
# 82.0          INCLUDE            NaN        NaN                        Yes.
# 526.0         INCLUDE            NaN        NaN                        Yes.
# 1795.0        EXCLUDE            NaN        NaN                         Yes
# 1179.0        EXCLUDE            NaN        NaN                         Yes
#
# [100 rows x 13 columns]

# %%
train_b7.to_excel("chatgpt_responses_b7.xlsx")

# %%
print(classification_report(train_b7["Final decision"] == "INCLUDE", train_b7["chatgpt"].apply(lambda x: int("Yes" in x)), digits=4))

# %%
chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
# Out:
# 'Yes'

# %%
# %%time
b = "Does the article address limitations, challenges, and potential risks?"
b = b.replace("article", "abstract")
responses = []
for i, ix in enumerate(chatgpt_train_sample.index):
    t, a, label = chatgpt_train_sample.loc[ix]["Article Title  Abstract (AB)  Final decision".split("  ")]
    a = a.replace("\n", " ")
    a = " ".join(a.split(" ")).strip()
    o = chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
    o = o.replace("\n", " ").strip()
    responses.append([ix, o])
    print(100*(i+1)/chatgpt_train_sample.shape[0], ix, o, label)
# Out:
# 1.0 232.0 No. INCLUDE
# 2.0 1761.0 Yes. The abstract mentions INCLUDE
# 3.0 792.0 No. EXCLUDE
# 4.0 405.0 Yes INCLUDE
# 5.0 1396.0 Yes. EXCLUDE
# 6.0 433.0 Yes EXCLUDE
# 7.0 543.0 Yes. The abstract mentions EXCLUDE
# 8.0 412.0 No INCLUDE
# 9.0 1397.0 No. EXCLUDE
# 10.0 688.0 Yes. INCLUDE
# 11.0 743.0 Yes. The abstract mentions EXCLUDE
# 12.0 1222.0 No EXCLUDE
# 13.0 329.0 Yes EXCLUDE
# 14.0 1365.0 No. EXCLUDE
# 15.0 677.0 Yes INCLUDE
# 16.0 1432.0 No. The abstract focuses INCLUDE
# 17.0 507.0 Yes EXCLUDE
# 18.0 1302.0 Yes EXCLUDE
# 19.0 847.0 No. INCLUDE
# 20.0 1580.0 Yes. The abstract mentions EXCLUDE
# 21.0 1700.0 No. EXCLUDE
# 22.0 920.0 Yes INCLUDE
# 23.0 987.0 Yes. The abstract addresses INCLUDE
# 24.0 1673.0 No INCLUDE
# 25.0 312.0 Yes. INCLUDE
# 26.0 444.0 No. EXCLUDE
# 27.0 1171.0 Yes INCLUDE
# 28.0 1448.0 No. EXCLUDE
# 29.0 1808.0 No. EXCLUDE
# 30.0 734.0 Yes INCLUDE
# 31.0 430.0 No. The abstract only INCLUDE
# 32.0 423.0 Yes. INCLUDE
# 33.0 718.0 Yes. EXCLUDE
# 34.0 828.0 No EXCLUDE
# 35.0 124.0 No. The abstract only EXCLUDE
# 36.0 1088.0 No. EXCLUDE
# 37.0 1172.0 Yes EXCLUDE
# 38.0 38.0 No. INCLUDE
# 39.0 355.0 Yes EXCLUDE
# 40.0 1460.0 Yes EXCLUDE
# 41.0 930.0 Yes. The abstract addresses EXCLUDE
# 42.0 574.0 Yes EXCLUDE
# 43.0 168.0 No. INCLUDE
# 44.0 362.0 No INCLUDE
# 45.0 1136.0 No. INCLUDE
# 46.0 502.0 Yes. The abstract discusses EXCLUDE
# 47.0 169.0 Yes. The abstract mentions EXCLUDE
# 48.0 1979.0 Yes INCLUDE
# 49.0 324.0 Yes INCLUDE
# 50.0 1546.0 No. INCLUDE
# 51.0 1099.0 Yes INCLUDE
# 52.0 1187.0 No EXCLUDE
# 53.0 892.0 Yes. EXCLUDE
# 54.0 691.0 Yes. The abstract mentions EXCLUDE
# 55.0 1380.0 No. EXCLUDE
# 56.0 1841.0 No INCLUDE
# 57.0 177.0 Yes INCLUDE
# 58.0 1563.0 No. INCLUDE
# 59.0 1893.0 No. EXCLUDE
# 60.0 254.0 No. EXCLUDE
# 61.0 34.0 No EXCLUDE
# 62.0 325.0 Yes. The abstract discusses EXCLUDE
# 63.0 222.0 No. EXCLUDE
# 64.0 1671.0 No. INCLUDE
# 65.0 114.0 Yes EXCLUDE
# 66.0 126.0 No. EXCLUDE
# 67.0 215.0 Yes. The abstract mentions INCLUDE
# 68.0 785.0 No. EXCLUDE
# 69.0 894.0 Yes INCLUDE
# 70.0 1793.0 No. INCLUDE
# 71.0 316.0 Yes. The abstract addresses EXCLUDE
# 72.0 1727.0 Yes. The abstract mentions INCLUDE
# 73.0 320.0 Yes. EXCLUDE
# 74.0 204.0 Yes EXCLUDE
# 75.0 565.0 Yes. The abstract suggests INCLUDE
# 76.0 1665.0 No. EXCLUDE
# 77.0 144.0 No INCLUDE
# 78.0 343.0 No. INCLUDE
# 79.0 1748.0 Yes EXCLUDE
# 80.0 1619.0 Yes. The abstract mentions INCLUDE
# 81.0 1057.0 Yes. The abstract addresses EXCLUDE
# 82.0 890.0 Yes EXCLUDE
# 83.0 1659.0 Yes EXCLUDE
# 84.0 1543.0 No. EXCLUDE
# 85.0 1216.0 Yes. The abstract discusses EXCLUDE
# 86.0 616.0 No. EXCLUDE
# 87.0 1314.0 Yes. The abstract mentions INCLUDE
# 88.0 510.0 Yes INCLUDE
# 89.0 73.0 No. EXCLUDE
# 90.0 1245.0 No. INCLUDE
# 91.0 1871.0 No INCLUDE
# 92.0 1472.0 Yes. EXCLUDE
# 93.0 371.0 Yes INCLUDE
# 94.0 604.0 No. INCLUDE
# 95.0 889.0 No. EXCLUDE
# 96.0 1758.0 Yes INCLUDE
# 97.0 82.0 Yes. The abstract discusses INCLUDE
# 98.0 526.0 No. INCLUDE
# 99.0 1795.0 No. EXCLUDE
# 100.0 1179.0 No. EXCLUDE

# %%
train_b8 = chatgpt_train_sample.copy()
train_b8["chatgpt"] = [x[1] for x in responses]
train_b8
# Out:
#        Publication Type                                            Authors  \
# 232.0                 J                   Tang, K; He, CT; Ma, CB; Wang, D
# 1761.0                J  Allam, M; Radicetti, E; Quintarelli, V; Petros...
# 792.0                 J     Raihan, A; Said, MNM; Abdullah, SMS; Begum, RA
# 405.0                 J  Wen, Y; Zang, HD; Freeman, B; Ma, QX; Chadwick...
# 1396.0                J        Dhanda, S; Yadav, A; Yadav, DB; Chauhan, BS
# ...                 ...                                                ...
# 1758.0                J  Carter, MS; Hauggaard-Nielsen, H; Heiske, S; J...
# 82.0                  J               Huang, JX; Chen, YQ; Sui, P; Gao, WS
# 526.0                 J                                         Everest, B
# 1795.0                J                Gancone, A; Pubule, J; Blumberga, D
# 1179.0                J  Tian, Z; Niu, YL; Fan, DL; Sun, LX; Ficsher, G...
#
#                                             Article Title  \
# 232.0   Does carbon farming provide a cost-effective o...
# 1761.0  Influence of Organic and Mineral Fertilizers o...
# 792.0   Climate Change Mitigation Options in the Fores...
# 405.0   Rye cover crop incorporation and high watertab...
# 1396.0  Emerging Issues and Potential Opportunities in...
# ...                                                   ...
# 1758.0  Consequences of field N2O emissions for the en...
# 82.0    Estimation of net greenhouse gas balance using...
# 526.0   Farmers' adaptation to climate-smart agricultu...
# 1795.0  Valorization Methodology for Agriculture Secto...
# 1179.0  Maintaining rice production while mitigating m...
#
#                                             Abstract (AB)  Publication Year  \
# 232.0   In this study, we apply a whole farm bioeconom...            2019.0
# 1761.0  The intensive use of mineral (M) fertilizers m...            2022.0
# 792.0   The Intergovernmental Panel on Climate Change ...            2018.0
# 405.0   Drainage and cultivation of peat soils almost ...            2019.0
# 1396.0  The rice-wheat cropping system (RWCS) is the b...            2022.0
# ...                                                   ...               ...
# 1758.0  One way of reducing the emissions of fossil fu...            2012.0
# 82.0    The net greenhouse gas balance (NGHGB), estima...            2013.0
# 526.0   Some of the measures to be taken to reduce gre...            2021.0
# 1795.0  Agriculture sector holds an essential role in ...            2021.0
# 1179.0  China is the largest rice producing and consum...            2018.0
#
#                                      DOI Researcher1 Researcher2 Researcher3  \
# 232.0            10.1111/1467-8489.12306     INCLUDE         NaN     INCLUDE
# 1761.0       10.3390/agriculture12040464     INCLUDE         NaN     INCLUDE
# 792.0      10.17576/jkukm-2018-si1(6)-11     EXCLUDE         NaN     EXCLUDE
# 405.0                   10.1002/ldr.3390         NaN     INCLUDE     INCLUDE
# 1396.0          10.3389/fpls.2022.832683         NaN     EXCLUDE     EXCLUDE
# ...                                  ...         ...         ...         ...
# 1758.0  10.1111/j.1757-1707.2011.01132.x     INCLUDE         NaN     INCLUDE
# 82.0     10.1016/j.scitotenv.2013.03.035     INCLUDE     INCLUDE         NaN
# 526.0         10.1007/s10668-020-00767-1         NaN     INCLUDE     INCLUDE
# 1795.0          10.2478/rtuect-2021-0071     EXCLUDE         NaN     EXCLUDE
# 1179.0        10.1016/j.agsy.2017.04.006     EXCLUDE     INCLUDE     EXCLUDE
#
#        Final decision Review studies Duplicates                      chatgpt
# 232.0         INCLUDE            NaN        NaN                          No.
# 1761.0        INCLUDE         Review        NaN   Yes. The abstract mentions
# 792.0         EXCLUDE            NaN        NaN                          No.
# 405.0         INCLUDE            NaN        NaN                          Yes
# 1396.0        EXCLUDE            NaN        NaN                         Yes.
# ...               ...            ...        ...                          ...
# 1758.0        INCLUDE            NaN        NaN                          Yes
# 82.0          INCLUDE            NaN        NaN  Yes. The abstract discusses
# 526.0         INCLUDE            NaN        NaN                          No.
# 1795.0        EXCLUDE            NaN        NaN                          No.
# 1179.0        EXCLUDE            NaN        NaN                          No.
#
# [100 rows x 13 columns]

# %%
train_b8.to_excel("D:/github/abstract-prediction/chatgpt_responses_b8.xlsx")

# %%
print(classification_report(train_b8["Final decision"] == "INCLUDE", train_b8["chatgpt"].apply(lambda x: int("Yes" in x)), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#        False     0.5532    0.4727    0.5098        55
#         True     0.4528    0.5333    0.4898        45
#
#     accuracy                         0.5000       100
#    macro avg     0.5030    0.5030    0.4998       100
# weighted avg     0.5080    0.5000    0.5008       100

# %%
chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
# Out:
# 'No'

# %%
# %%time
b = "Does the article address policy implications?"
b = b.replace("article", "abstract")
responses = []
for i, ix in enumerate(chatgpt_train_sample.index):
    t, a, label = chatgpt_train_sample.loc[ix]["Article Title  Abstract (AB)  Final decision".split("  ")]
    a = a.replace("\n", " ")
    a = " ".join(a.split(" ")).strip()
    o = chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
    o = o.replace("\n", " ").strip()
    responses.append([ix, o])
    print(100*(i+1)/chatgpt_train_sample.shape[0], ix, o, label)
# Out:
# 1.0 232.0 Yes INCLUDE
# 2.0 1761.0 Yes INCLUDE
# 3.0 792.0 Yes. EXCLUDE
# 4.0 405.0 No. INCLUDE
# 5.0 1396.0 Yes EXCLUDE
# 6.0 433.0 Yes. EXCLUDE
# 7.0 543.0 Yes. EXCLUDE
# 8.0 412.0 Yes INCLUDE
# 9.0 1397.0 Yes EXCLUDE
# 10.0 688.0 Yes INCLUDE
# 11.0 743.0 No EXCLUDE
# 12.0 1222.0 Yes EXCLUDE
# 13.0 329.0 No EXCLUDE
# 14.0 1365.0 Yes EXCLUDE
# 15.0 677.0 Yes INCLUDE
# 16.0 1432.0 Yes. INCLUDE
# 17.0 507.0 Yes EXCLUDE
# 18.0 1302.0 No EXCLUDE
# 19.0 847.0 Yes INCLUDE
# 20.0 1580.0 Yes EXCLUDE
# 21.0 1700.0 Yes. EXCLUDE
# 22.0 920.0 No. INCLUDE
# 23.0 987.0 Yes INCLUDE
# 24.0 1673.0 No INCLUDE
# 25.0 312.0 No. INCLUDE
# 26.0 444.0 Yes EXCLUDE
# 27.0 1171.0 No INCLUDE
# 28.0 1448.0 No. EXCLUDE
# 29.0 1808.0 Yes EXCLUDE
# 30.0 734.0 Yes INCLUDE
# 31.0 430.0 No INCLUDE
# 32.0 423.0 Yes INCLUDE
# 33.0 718.0 Yes EXCLUDE
# 34.0 828.0 Yes EXCLUDE
# 35.0 124.0 Yes EXCLUDE
# 36.0 1088.0 No EXCLUDE
# 37.0 1172.0 No. EXCLUDE
# 38.0 38.0 Yes. INCLUDE
# 39.0 355.0 Yes EXCLUDE
# 40.0 1460.0 Yes. EXCLUDE
# 41.0 930.0 Yes EXCLUDE
# 42.0 574.0 No. EXCLUDE
# 43.0 168.0 Yes. INCLUDE
# 44.0 362.0 No. INCLUDE
# 45.0 1136.0 Yes INCLUDE
# 46.0 502.0 Yes EXCLUDE
# 47.0 169.0 No EXCLUDE
# 48.0 1979.0 Yes INCLUDE
# 49.0 324.0 Yes INCLUDE
# 50.0 1546.0 Yes INCLUDE
# 51.0 1099.0 No. INCLUDE
# 52.0 1187.0 No EXCLUDE
# 53.0 892.0 No. EXCLUDE
# 54.0 691.0 Yes EXCLUDE
# 55.0 1380.0 Yes. EXCLUDE
# 56.0 1841.0 No. INCLUDE
# 57.0 177.0 No. INCLUDE
# 58.0 1563.0 Yes INCLUDE
# 59.0 1893.0 Yes. EXCLUDE
# 60.0 254.0 Yes. EXCLUDE
# 61.0 34.0 No EXCLUDE
# 62.0 325.0 Yes. EXCLUDE
# 63.0 222.0 Yes EXCLUDE
# 64.0 1671.0 Yes INCLUDE
# 65.0 114.0 Yes EXCLUDE
# 66.0 126.0 No EXCLUDE
# 67.0 215.0 Yes INCLUDE
# 68.0 785.0 Yes EXCLUDE
# 69.0 894.0 Yes INCLUDE
# 70.0 1793.0 Yes. INCLUDE
# 71.0 316.0 Yes EXCLUDE
# 72.0 1727.0 Yes. INCLUDE
# 73.0 320.0 Yes. EXCLUDE
# 74.0 204.0 No. EXCLUDE
# 75.0 565.0 Yes INCLUDE
# 76.0 1665.0 Yes EXCLUDE
# 77.0 144.0 Yes INCLUDE
# 78.0 343.0 No. INCLUDE
# 79.0 1748.0 Yes EXCLUDE
# 80.0 1619.0 Yes INCLUDE
# 81.0 1057.0 Yes EXCLUDE
# 82.0 890.0 Yes EXCLUDE
# 83.0 1659.0 Yes. EXCLUDE
# 84.0 1543.0 No. EXCLUDE
# 85.0 1216.0 Yes EXCLUDE
# 86.0 616.0 Yes EXCLUDE
# 87.0 1314.0 Yes INCLUDE
# 88.0 510.0 Yes INCLUDE
# 89.0 73.0 Yes EXCLUDE
# 90.0 1245.0 No. INCLUDE
# 91.0 1871.0 No INCLUDE
# 92.0 1472.0 Yes. EXCLUDE
# 93.0 371.0 Yes. INCLUDE
# 94.0 604.0 Yes INCLUDE
# 95.0 889.0 No. EXCLUDE
# 96.0 1758.0 Yes INCLUDE
# 97.0 82.0 No. INCLUDE
# 98.0 526.0 Yes INCLUDE
# 99.0 1795.0 Yes EXCLUDE
# 100.0 1179.0 Yes EXCLUDE
# Wall time: 2min 7s

# %%
train_b9 = chatgpt_train_sample.copy()
train_b9["chatgpt"] = [x[1] for x in responses]
train_b9
# Out:
#        Publication Type                                            Authors  \
# 232.0                 J                   Tang, K; He, CT; Ma, CB; Wang, D
# 1761.0                J  Allam, M; Radicetti, E; Quintarelli, V; Petros...
# 792.0                 J     Raihan, A; Said, MNM; Abdullah, SMS; Begum, RA
# 405.0                 J  Wen, Y; Zang, HD; Freeman, B; Ma, QX; Chadwick...
# 1396.0                J        Dhanda, S; Yadav, A; Yadav, DB; Chauhan, BS
# ...                 ...                                                ...
# 1758.0                J  Carter, MS; Hauggaard-Nielsen, H; Heiske, S; J...
# 82.0                  J               Huang, JX; Chen, YQ; Sui, P; Gao, WS
# 526.0                 J                                         Everest, B
# 1795.0                J                Gancone, A; Pubule, J; Blumberga, D
# 1179.0                J  Tian, Z; Niu, YL; Fan, DL; Sun, LX; Ficsher, G...
#
#                                             Article Title  \
# 232.0   Does carbon farming provide a cost-effective o...
# 1761.0  Influence of Organic and Mineral Fertilizers o...
# 792.0   Climate Change Mitigation Options in the Fores...
# 405.0   Rye cover crop incorporation and high watertab...
# 1396.0  Emerging Issues and Potential Opportunities in...
# ...                                                   ...
# 1758.0  Consequences of field N2O emissions for the en...
# 82.0    Estimation of net greenhouse gas balance using...
# 526.0   Farmers' adaptation to climate-smart agricultu...
# 1795.0  Valorization Methodology for Agriculture Secto...
# 1179.0  Maintaining rice production while mitigating m...
#
#                                             Abstract (AB)  Publication Year  \
# 232.0   In this study, we apply a whole farm bioeconom...            2019.0
# 1761.0  The intensive use of mineral (M) fertilizers m...            2022.0
# 792.0   The Intergovernmental Panel on Climate Change ...            2018.0
# 405.0   Drainage and cultivation of peat soils almost ...            2019.0
# 1396.0  The rice-wheat cropping system (RWCS) is the b...            2022.0
# ...                                                   ...               ...
# 1758.0  One way of reducing the emissions of fossil fu...            2012.0
# 82.0    The net greenhouse gas balance (NGHGB), estima...            2013.0
# 526.0   Some of the measures to be taken to reduce gre...            2021.0
# 1795.0  Agriculture sector holds an essential role in ...            2021.0
# 1179.0  China is the largest rice producing and consum...            2018.0
#
#                                      DOI Researcher1 Researcher2 Researcher3  \
# 232.0            10.1111/1467-8489.12306     INCLUDE         NaN     INCLUDE
# 1761.0       10.3390/agriculture12040464     INCLUDE         NaN     INCLUDE
# 792.0      10.17576/jkukm-2018-si1(6)-11     EXCLUDE         NaN     EXCLUDE
# 405.0                   10.1002/ldr.3390         NaN     INCLUDE     INCLUDE
# 1396.0          10.3389/fpls.2022.832683         NaN     EXCLUDE     EXCLUDE
# ...                                  ...         ...         ...         ...
# 1758.0  10.1111/j.1757-1707.2011.01132.x     INCLUDE         NaN     INCLUDE
# 82.0     10.1016/j.scitotenv.2013.03.035     INCLUDE     INCLUDE         NaN
# 526.0         10.1007/s10668-020-00767-1         NaN     INCLUDE     INCLUDE
# 1795.0          10.2478/rtuect-2021-0071     EXCLUDE         NaN     EXCLUDE
# 1179.0        10.1016/j.agsy.2017.04.006     EXCLUDE     INCLUDE     EXCLUDE
#
#        Final decision Review studies Duplicates chatgpt
# 232.0         INCLUDE            NaN        NaN     Yes
# 1761.0        INCLUDE         Review        NaN     Yes
# 792.0         EXCLUDE            NaN        NaN    Yes.
# 405.0         INCLUDE            NaN        NaN     No.
# 1396.0        EXCLUDE            NaN        NaN     Yes
# ...               ...            ...        ...     ...
# 1758.0        INCLUDE            NaN        NaN     Yes
# 82.0          INCLUDE            NaN        NaN     No.
# 526.0         INCLUDE            NaN        NaN     Yes
# 1795.0        EXCLUDE            NaN        NaN     Yes
# 1179.0        EXCLUDE            NaN        NaN     Yes
#
# [100 rows x 13 columns]

# %%
train_b9.to_excel("D:/github/abstract-prediction/chatgpt_responses_b9.xlsx")

# %%
print(classification_report(train_b9["Final decision"] == "INCLUDE", train_b9["chatgpt"].apply(lambda x: int("Yes" in x)), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#        False     0.5172    0.2727    0.3571        55
#         True     0.4366    0.6889    0.5345        45
#
#     accuracy                         0.4600       100
#    macro avg     0.4769    0.4808    0.4458       100
# weighted avg     0.4810    0.4600    0.4369       100

# %%
# %%time
b = "Does the article have a specific geographic focus?"
b = b.replace("article", "abstract")
responses = []
for i, ix in enumerate(chatgpt_train_sample.index):
    t, a, label = chatgpt_train_sample.loc[ix]["Article Title  Abstract (AB)  Final decision".split("  ")]
    a = a.replace("\n", " ")
    a = " ".join(a.split(" ")).strip()
    o = chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
    o = o.replace("\n", " ").strip()
    responses.append([ix, o])
    print(100*(i+1)/chatgpt_train_sample.shape[0], ix, o, label)
# Out:
# 1.0 232.0 Yes INCLUDE
# 2.0 1761.0 No. INCLUDE
# 3.0 792.0 Yes EXCLUDE
# 4.0 405.0 No INCLUDE
# 5.0 1396.0 Yes EXCLUDE
# 6.0 433.0 No. EXCLUDE
# 7.0 543.0 Yes EXCLUDE
# 8.0 412.0 No. INCLUDE
# 9.0 1397.0 Yes. EXCLUDE
# 10.0 688.0 Yes INCLUDE
# 11.0 743.0 Yes EXCLUDE
# 12.0 1222.0 Yes. The abstract mentions EXCLUDE
# 13.0 329.0 No EXCLUDE
# 14.0 1365.0 Yes EXCLUDE
# 15.0 677.0 No. INCLUDE
# 16.0 1432.0 Yes INCLUDE
# 17.0 507.0 No EXCLUDE
# 18.0 1302.0 Yes EXCLUDE
# 19.0 847.0 Yes. The abstract indicates INCLUDE
# 20.0 1580.0 No. EXCLUDE
# 21.0 1700.0 Yes. The abstract has EXCLUDE
# 22.0 920.0 Yes INCLUDE
# 23.0 987.0 Yes INCLUDE
# 24.0 1673.0 No INCLUDE
# 25.0 312.0 Yes INCLUDE
# 26.0 444.0 No EXCLUDE
# 27.0 1171.0 Yes. The abstract mentions INCLUDE
# 28.0 1448.0 Yes EXCLUDE
# 29.0 1808.0 Yes. EXCLUDE
# 30.0 734.0 No INCLUDE
# 31.0 430.0 Yes. The abstract mentions INCLUDE
# 32.0 423.0 Yes. INCLUDE
# 33.0 718.0 Yes EXCLUDE
# 34.0 828.0 No EXCLUDE
# 35.0 124.0 Yes. The abstract specifies EXCLUDE
# 36.0 1088.0 Yes. The abstract mentions EXCLUDE
# 37.0 1172.0 No. EXCLUDE
# 38.0 38.0 Yes. The abstract mentions INCLUDE
# 39.0 355.0 No EXCLUDE
# 40.0 1460.0 Yes EXCLUDE
# 41.0 930.0 Yes EXCLUDE
# 42.0 574.0 Yes. EXCLUDE
# 43.0 168.0 No INCLUDE
# 44.0 362.0 Yes INCLUDE
# 45.0 1136.0 Yes INCLUDE
# 46.0 502.0 Yes. The abstract mentions EXCLUDE
# 47.0 169.0 No. EXCLUDE
# 48.0 1979.0 No INCLUDE
# 49.0 324.0 Yes INCLUDE
# 50.0 1546.0 Yes INCLUDE
# 51.0 1099.0 Yes. INCLUDE
# 52.0 1187.0 No EXCLUDE
# 53.0 892.0 No EXCLUDE
# 54.0 691.0 Yes EXCLUDE
# 55.0 1380.0 Yes EXCLUDE
# 56.0 1841.0 Yes. INCLUDE
# 57.0 177.0 No INCLUDE
# 58.0 1563.0 Yes INCLUDE
# 59.0 1893.0 Yes EXCLUDE
# 60.0 254.0 Yes EXCLUDE
# 61.0 34.0 Yes EXCLUDE
# 62.0 325.0 Yes EXCLUDE
# 63.0 222.0 Yes EXCLUDE
# 64.0 1671.0 Yes INCLUDE
# 65.0 114.0 No EXCLUDE
# 66.0 126.0 Yes EXCLUDE
# 67.0 215.0 No INCLUDE
# 68.0 785.0 Yes EXCLUDE
# 69.0 894.0 Yes INCLUDE
# 70.0 1793.0 Yes INCLUDE
# 71.0 316.0 Yes EXCLUDE
# 72.0 1727.0 Yes. INCLUDE
# 73.0 320.0 Yes. EXCLUDE
# 74.0 204.0 No EXCLUDE
# 75.0 565.0 Yes. The abstract mentions INCLUDE
# 76.0 1665.0 No EXCLUDE
# 77.0 144.0 Yes. The abstract mentions INCLUDE
# 78.0 343.0 No INCLUDE
# 79.0 1748.0 Yes EXCLUDE
# 80.0 1619.0 Yes INCLUDE
# 81.0 1057.0 Yes EXCLUDE
# Thinking...
# 82.0 890.0 Yes EXCLUDE
# 83.0 1659.0 Yes EXCLUDE
# 84.0 1543.0 No EXCLUDE
# 85.0 1216.0 Yes EXCLUDE
# 86.0 616.0 Yes. The abstract has EXCLUDE
# 87.0 1314.0 Yes INCLUDE
# 88.0 510.0 No INCLUDE
# 89.0 73.0 No. EXCLUDE
# 90.0 1245.0 No. INCLUDE
# 91.0 1871.0 Yes. INCLUDE
# 92.0 1472.0 No. EXCLUDE
# 93.0 371.0 Yes INCLUDE
# 94.0 604.0 Yes INCLUDE
# 95.0 889.0 Yes. EXCLUDE
# 96.0 1758.0 No INCLUDE
# 97.0 82.0 No INCLUDE
# Thinking...
# 98.0 526.0 Yes INCLUDE
# 99.0 1795.0 Yes. The abstract specifically EXCLUDE
# 100.0 1179.0 Yes EXCLUDE
# Wall time: 3min 7s

# %%
train_b10 = chatgpt_train_sample.copy()
train_b10["chatgpt"] = [x[1] for x in responses]
train_b10
# Out:
#        Publication Type                                            Authors  \
# 232.0                 J                   Tang, K; He, CT; Ma, CB; Wang, D
# 1761.0                J  Allam, M; Radicetti, E; Quintarelli, V; Petros...
# 792.0                 J     Raihan, A; Said, MNM; Abdullah, SMS; Begum, RA
# 405.0                 J  Wen, Y; Zang, HD; Freeman, B; Ma, QX; Chadwick...
# 1396.0                J        Dhanda, S; Yadav, A; Yadav, DB; Chauhan, BS
# ...                 ...                                                ...
# 1758.0                J  Carter, MS; Hauggaard-Nielsen, H; Heiske, S; J...
# 82.0                  J               Huang, JX; Chen, YQ; Sui, P; Gao, WS
# 526.0                 J                                         Everest, B
# 1795.0                J                Gancone, A; Pubule, J; Blumberga, D
# 1179.0                J  Tian, Z; Niu, YL; Fan, DL; Sun, LX; Ficsher, G...
#
#                                             Article Title  \
# 232.0   Does carbon farming provide a cost-effective o...
# 1761.0  Influence of Organic and Mineral Fertilizers o...
# 792.0   Climate Change Mitigation Options in the Fores...
# 405.0   Rye cover crop incorporation and high watertab...
# 1396.0  Emerging Issues and Potential Opportunities in...
# ...                                                   ...
# 1758.0  Consequences of field N2O emissions for the en...
# 82.0    Estimation of net greenhouse gas balance using...
# 526.0   Farmers' adaptation to climate-smart agricultu...
# 1795.0  Valorization Methodology for Agriculture Secto...
# 1179.0  Maintaining rice production while mitigating m...
#
#                                             Abstract (AB)  Publication Year  \
# 232.0   In this study, we apply a whole farm bioeconom...            2019.0
# 1761.0  The intensive use of mineral (M) fertilizers m...            2022.0
# 792.0   The Intergovernmental Panel on Climate Change ...            2018.0
# 405.0   Drainage and cultivation of peat soils almost ...            2019.0
# 1396.0  The rice-wheat cropping system (RWCS) is the b...            2022.0
# ...                                                   ...               ...
# 1758.0  One way of reducing the emissions of fossil fu...            2012.0
# 82.0    The net greenhouse gas balance (NGHGB), estima...            2013.0
# 526.0   Some of the measures to be taken to reduce gre...            2021.0
# 1795.0  Agriculture sector holds an essential role in ...            2021.0
# 1179.0  China is the largest rice producing and consum...            2018.0
#
#                                      DOI Researcher1 Researcher2 Researcher3  \
# 232.0            10.1111/1467-8489.12306     INCLUDE         NaN     INCLUDE
# 1761.0       10.3390/agriculture12040464     INCLUDE         NaN     INCLUDE
# 792.0      10.17576/jkukm-2018-si1(6)-11     EXCLUDE         NaN     EXCLUDE
# 405.0                   10.1002/ldr.3390         NaN     INCLUDE     INCLUDE
# 1396.0          10.3389/fpls.2022.832683         NaN     EXCLUDE     EXCLUDE
# ...                                  ...         ...         ...         ...
# 1758.0  10.1111/j.1757-1707.2011.01132.x     INCLUDE         NaN     INCLUDE
# 82.0     10.1016/j.scitotenv.2013.03.035     INCLUDE     INCLUDE         NaN
# 526.0         10.1007/s10668-020-00767-1         NaN     INCLUDE     INCLUDE
# 1795.0          10.2478/rtuect-2021-0071     EXCLUDE         NaN     EXCLUDE
# 1179.0        10.1016/j.agsy.2017.04.006     EXCLUDE     INCLUDE     EXCLUDE
#
#        Final decision Review studies Duplicates  \
# 232.0         INCLUDE            NaN        NaN
# 1761.0        INCLUDE         Review        NaN
# 792.0         EXCLUDE            NaN        NaN
# 405.0         INCLUDE            NaN        NaN
# 1396.0        EXCLUDE            NaN        NaN
# ...               ...            ...        ...
# 1758.0        INCLUDE            NaN        NaN
# 82.0          INCLUDE            NaN        NaN
# 526.0         INCLUDE            NaN        NaN
# 1795.0        EXCLUDE            NaN        NaN
# 1179.0        EXCLUDE            NaN        NaN
#
#                                chatgpt
# 232.0                              Yes
# 1761.0                             No.
# 792.0                              Yes
# 405.0                               No
# 1396.0                             Yes
# ...                                ...
# 1758.0                              No
# 82.0                                No
# 526.0                              Yes
# 1795.0  Yes. The abstract specifically
# 1179.0                             Yes
#
# [100 rows x 13 columns]

# %%
train_b10.to_excel("D:/github/abstract-prediction/chatgpt_responses_b10.xlsx")

# %%
print(classification_report(train_b10["Final decision"] == "INCLUDE", train_b10["chatgpt"].apply(lambda x: int("Yes" in x)), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#        False     0.5312    0.3091    0.3908        55
#         True     0.4412    0.6667    0.5310        45
#
#     accuracy                         0.4700       100
#    macro avg     0.4862    0.4879    0.4609       100
# weighted avg     0.4907    0.4700    0.4539       100

# %%
# %%time
b = "Does the article discuss the role of agroecology in enhancing climate resilience in agricultural systems?"
b = b.replace("article", "abstract")
responses = []
for i, ix in enumerate(chatgpt_train_sample.index):
    t, a, label = chatgpt_train_sample.loc[ix]["Article Title  Abstract (AB)  Final decision".split("  ")]
    a = a.replace("\n", " ")
    a = " ".join(a.split(" ")).strip()
    o = chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
    o = o.replace("\n", " ").strip()
    responses.append([ix, o])
    print(100*(i+1)/chatgpt_train_sample.shape[0], ix, o, label)
# Out:
# 1.0 232.0 No. INCLUDE
# 2.0 1761.0 No. INCLUDE
# 3.0 792.0 No EXCLUDE
# 4.0 405.0 Yes INCLUDE
# 5.0 1396.0 No. EXCLUDE
# 6.0 433.0 The abstract does not mention EXCLUDE
# 7.0 543.0 No. EXCLUDE
# 8.0 412.0 Yes INCLUDE
# 9.0 1397.0 Yes. EXCLUDE
# 10.0 688.0 Yes INCLUDE
# 11.0 743.0 No. EXCLUDE
# 12.0 1222.0 No. EXCLUDE
# 13.0 329.0 No. The abstract discusses EXCLUDE
# 14.0 1365.0 No. EXCLUDE
# 15.0 677.0 No. The abstract discusses INCLUDE
# 16.0 1432.0 Yes. INCLUDE
# 17.0 507.0 Yes. EXCLUDE
# 18.0 1302.0 No. The abstract discusses EXCLUDE
# 19.0 847.0 Yes INCLUDE
# 20.0 1580.0 No. EXCLUDE
# 21.0 1700.0 No. EXCLUDE
# 22.0 920.0 No. INCLUDE
# 23.0 987.0 No. INCLUDE
# 24.0 1673.0 Yes. INCLUDE
# 25.0 312.0 Yes INCLUDE
# 26.0 444.0 No. EXCLUDE
# 27.0 1171.0 No. INCLUDE
# 28.0 1448.0 No. EXCLUDE
# 29.0 1808.0 No. EXCLUDE
# 30.0 734.0 Yes INCLUDE
# 31.0 430.0 Yes INCLUDE
# 32.0 423.0 No. INCLUDE
# 33.0 718.0 Yes. EXCLUDE
# 34.0 828.0 No EXCLUDE
# 35.0 124.0 Yes. EXCLUDE
# 36.0 1088.0 Yes. EXCLUDE
# 37.0 1172.0 Yes EXCLUDE
# 38.0 38.0 Yes. INCLUDE
# 39.0 355.0 No. EXCLUDE
# 40.0 1460.0 No. EXCLUDE
# 41.0 930.0 No. EXCLUDE
# 42.0 574.0 No. EXCLUDE
# 43.0 168.0 Yes INCLUDE
# 44.0 362.0 No. INCLUDE
# 45.0 1136.0 Yes. INCLUDE
# 46.0 502.0 Yes EXCLUDE
# 47.0 169.0 No. The abstract discusses EXCLUDE
# 48.0 1979.0 The abstract does not explicitly INCLUDE
# 49.0 324.0 No. INCLUDE
# 50.0 1546.0 No. INCLUDE
# 51.0 1099.0 No. INCLUDE
# 52.0 1187.0 Yes. EXCLUDE
# 53.0 892.0 No EXCLUDE
# 54.0 691.0 No. EXCLUDE
# 55.0 1380.0 Yes. EXCLUDE
# 56.0 1841.0 No. INCLUDE
# 57.0 177.0 No. INCLUDE
# 58.0 1563.0 Yes INCLUDE
# 59.0 1893.0 No. EXCLUDE
# 60.0 254.0 No. EXCLUDE
# 61.0 34.0 No EXCLUDE
# 62.0 325.0 No. EXCLUDE
# 63.0 222.0 No. EXCLUDE
# 64.0 1671.0 No. INCLUDE
# 65.0 114.0 No. EXCLUDE
# 66.0 126.0 No. EXCLUDE
# 67.0 215.0 Yes INCLUDE
# 68.0 785.0 No. EXCLUDE
# 69.0 894.0 Yes. INCLUDE
# 70.0 1793.0 Yes. INCLUDE
# 71.0 316.0 Yes. EXCLUDE
# 72.0 1727.0 Yes INCLUDE
# 73.0 320.0 Yes. EXCLUDE
# 74.0 204.0 Yes EXCLUDE
# 75.0 565.0 Yes. INCLUDE
# 76.0 1665.0 No EXCLUDE
# 77.0 144.0 Yes. INCLUDE
# 78.0 343.0 Yes. INCLUDE
# 79.0 1748.0 Yes. EXCLUDE
# 80.0 1619.0 Yes. The abstract discusses INCLUDE
# 81.0 1057.0 No. EXCLUDE
# 82.0 890.0 No. EXCLUDE
# 83.0 1659.0 No. EXCLUDE
# 84.0 1543.0 No EXCLUDE
# 85.0 1216.0 No. EXCLUDE
# 86.0 616.0 No EXCLUDE
# 87.0 1314.0 Yes. INCLUDE
# 88.0 510.0 No. INCLUDE
# 89.0 73.0 No. EXCLUDE
# 90.0 1245.0 No. INCLUDE
# 91.0 1871.0 No. INCLUDE
# 92.0 1472.0 No. EXCLUDE
# 93.0 371.0 Yes. INCLUDE
# 94.0 604.0 No. INCLUDE
# 95.0 889.0 Yes. EXCLUDE
# 96.0 1758.0 Yes. INCLUDE
# 97.0 82.0 No. INCLUDE
# 98.0 526.0 No. INCLUDE
# 99.0 1795.0 No. EXCLUDE
# 100.0 1179.0 Yes. EXCLUDE
# Wall time: 1min 41s

# %%
train_b11 = chatgpt_train_sample.copy()
train_b11["chatgpt"] = [x[1] for x in responses]
train_b11
# Out:
#        Publication Type                                            Authors  \
# 232.0                 J                   Tang, K; He, CT; Ma, CB; Wang, D
# 1761.0                J  Allam, M; Radicetti, E; Quintarelli, V; Petros...
# 792.0                 J     Raihan, A; Said, MNM; Abdullah, SMS; Begum, RA
# 405.0                 J  Wen, Y; Zang, HD; Freeman, B; Ma, QX; Chadwick...
# 1396.0                J        Dhanda, S; Yadav, A; Yadav, DB; Chauhan, BS
# ...                 ...                                                ...
# 1758.0                J  Carter, MS; Hauggaard-Nielsen, H; Heiske, S; J...
# 82.0                  J               Huang, JX; Chen, YQ; Sui, P; Gao, WS
# 526.0                 J                                         Everest, B
# 1795.0                J                Gancone, A; Pubule, J; Blumberga, D
# 1179.0                J  Tian, Z; Niu, YL; Fan, DL; Sun, LX; Ficsher, G...
#
#                                             Article Title  \
# 232.0   Does carbon farming provide a cost-effective o...
# 1761.0  Influence of Organic and Mineral Fertilizers o...
# 792.0   Climate Change Mitigation Options in the Fores...
# 405.0   Rye cover crop incorporation and high watertab...
# 1396.0  Emerging Issues and Potential Opportunities in...
# ...                                                   ...
# 1758.0  Consequences of field N2O emissions for the en...
# 82.0    Estimation of net greenhouse gas balance using...
# 526.0   Farmers' adaptation to climate-smart agricultu...
# 1795.0  Valorization Methodology for Agriculture Secto...
# 1179.0  Maintaining rice production while mitigating m...
#
#                                             Abstract (AB)  Publication Year  \
# 232.0   In this study, we apply a whole farm bioeconom...            2019.0
# 1761.0  The intensive use of mineral (M) fertilizers m...            2022.0
# 792.0   The Intergovernmental Panel on Climate Change ...            2018.0
# 405.0   Drainage and cultivation of peat soils almost ...            2019.0
# 1396.0  The rice-wheat cropping system (RWCS) is the b...            2022.0
# ...                                                   ...               ...
# 1758.0  One way of reducing the emissions of fossil fu...            2012.0
# 82.0    The net greenhouse gas balance (NGHGB), estima...            2013.0
# 526.0   Some of the measures to be taken to reduce gre...            2021.0
# 1795.0  Agriculture sector holds an essential role in ...            2021.0
# 1179.0  China is the largest rice producing and consum...            2018.0
#
#                                      DOI Researcher1 Researcher2 Researcher3  \
# 232.0            10.1111/1467-8489.12306     INCLUDE         NaN     INCLUDE
# 1761.0       10.3390/agriculture12040464     INCLUDE         NaN     INCLUDE
# 792.0      10.17576/jkukm-2018-si1(6)-11     EXCLUDE         NaN     EXCLUDE
# 405.0                   10.1002/ldr.3390         NaN     INCLUDE     INCLUDE
# 1396.0          10.3389/fpls.2022.832683         NaN     EXCLUDE     EXCLUDE
# ...                                  ...         ...         ...         ...
# 1758.0  10.1111/j.1757-1707.2011.01132.x     INCLUDE         NaN     INCLUDE
# 82.0     10.1016/j.scitotenv.2013.03.035     INCLUDE     INCLUDE         NaN
# 526.0         10.1007/s10668-020-00767-1         NaN     INCLUDE     INCLUDE
# 1795.0          10.2478/rtuect-2021-0071     EXCLUDE         NaN     EXCLUDE
# 1179.0        10.1016/j.agsy.2017.04.006     EXCLUDE     INCLUDE     EXCLUDE
#
#        Final decision Review studies Duplicates chatgpt
# 232.0         INCLUDE            NaN        NaN     No.
# 1761.0        INCLUDE         Review        NaN     No.
# 792.0         EXCLUDE            NaN        NaN      No
# 405.0         INCLUDE            NaN        NaN     Yes
# 1396.0        EXCLUDE            NaN        NaN     No.
# ...               ...            ...        ...     ...
# 1758.0        INCLUDE            NaN        NaN    Yes.
# 82.0          INCLUDE            NaN        NaN     No.
# 526.0         INCLUDE            NaN        NaN     No.
# 1795.0        EXCLUDE            NaN        NaN     No.
# 1179.0        EXCLUDE            NaN        NaN    Yes.
#
# [100 rows x 13 columns]

# %%
train_b11.to_excel("D:/github/abstract-prediction/chatgpt_responses_b11.xlsx")

# %%
print(classification_report(train_b11["Final decision"] == "INCLUDE", train_b11["chatgpt"].apply(lambda x: int("Yes" in x)), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#        False     0.6557    0.7273    0.6897        55
#         True     0.6154    0.5333    0.5714        45
#
#     accuracy                         0.6400       100
#    macro avg     0.6356    0.6303    0.6305       100
# weighted avg     0.6376    0.6400    0.6365       100

# %%
# %%time
b = "Does the article assess the impact of agroecology on nitrogen dynamics?"
b = b.replace("article", "abstract")
responses = []
for i, ix in enumerate(chatgpt_train_sample.index):
    t, a, label = chatgpt_train_sample.loc[ix]["Article Title  Abstract (AB)  Final decision".split("  ")]
    a = a.replace("\n", " ")
    a = " ".join(a.split(" ")).strip()
    o = chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
    o = o.replace("\n", " ").strip()
    responses.append([ix, o])
    print(100*(i+1)/chatgpt_train_sample.shape[0], ix, o, label)
# Out:
# 1.0 232.0 No. The abstract does INCLUDE
# 2.0 1761.0 No. INCLUDE
# 3.0 792.0 No. EXCLUDE
# 4.0 405.0 Yes. INCLUDE
# 5.0 1396.0 No. EXCLUDE
# 6.0 433.0 No. EXCLUDE
# 7.0 543.0 No. EXCLUDE
# 8.0 412.0 No. INCLUDE
# 9.0 1397.0 Yes EXCLUDE
# 10.0 688.0 Yes INCLUDE
# 11.0 743.0 No. EXCLUDE
# 12.0 1222.0 No. EXCLUDE
# 13.0 329.0 No EXCLUDE
# 14.0 1365.0 No. EXCLUDE
# 15.0 677.0 No INCLUDE
# 16.0 1432.0 No. INCLUDE
# 17.0 507.0 Yes EXCLUDE
# 18.0 1302.0 No. EXCLUDE
# 19.0 847.0 No. INCLUDE
# 20.0 1580.0 No. EXCLUDE
# 21.0 1700.0 Yes. EXCLUDE
# 22.0 920.0 Yes INCLUDE
# 23.0 987.0 No INCLUDE
# 24.0 1673.0 Yes INCLUDE
# 25.0 312.0 Yes. INCLUDE
# 26.0 444.0 Yes. EXCLUDE
# 27.0 1171.0 Yes. INCLUDE
# 28.0 1448.0 No. EXCLUDE
# 29.0 1808.0 No. EXCLUDE
# 30.0 734.0 Yes INCLUDE
# 31.0 430.0 No. The abstract does INCLUDE
# Thinking...
# 32.0 423.0 Yes INCLUDE
# 33.0 718.0 No. EXCLUDE
# 34.0 828.0 No. EXCLUDE
# 35.0 124.0 Yes. EXCLUDE
# 36.0 1088.0 No. EXCLUDE
# 37.0 1172.0 No. EXCLUDE
# 38.0 38.0 Yes INCLUDE
# 39.0 355.0 No. EXCLUDE
# 40.0 1460.0 No. EXCLUDE
# 41.0 930.0 No. EXCLUDE
# 42.0 574.0 No. EXCLUDE
# 43.0 168.0 Yes. INCLUDE
# 44.0 362.0 No. INCLUDE
# 45.0 1136.0 No. INCLUDE
# 46.0 502.0 Yes. EXCLUDE
# 47.0 169.0 No EXCLUDE
# 48.0 1979.0 No. The abstract discusses INCLUDE
# 49.0 324.0 No. INCLUDE
# 50.0 1546.0 No. INCLUDE
# 51.0 1099.0 No. INCLUDE
# 52.0 1187.0 No. EXCLUDE
# 53.0 892.0 No. EXCLUDE
# 54.0 691.0 No. EXCLUDE
# 55.0 1380.0 No. The abstract does EXCLUDE
# 56.0 1841.0 Yes. INCLUDE
# 57.0 177.0 No INCLUDE
# 58.0 1563.0 Yes INCLUDE
# 59.0 1893.0 No. EXCLUDE
# 60.0 254.0 No. EXCLUDE
# 61.0 34.0 No. EXCLUDE
# 62.0 325.0 The abstract does not mention EXCLUDE
# 63.0 222.0 No EXCLUDE
# 64.0 1671.0 No. The abstract/title INCLUDE
# 65.0 114.0 No. EXCLUDE
# 66.0 126.0 No. EXCLUDE
# 67.0 215.0 Yes. INCLUDE
# 68.0 785.0 No. EXCLUDE
# 69.0 894.0 Yes. INCLUDE
# 70.0 1793.0 Yes. INCLUDE
# 71.0 316.0 No. EXCLUDE
# 72.0 1727.0 Yes. INCLUDE
# 73.0 320.0 No. EXCLUDE
# 74.0 204.0 No. EXCLUDE
# 75.0 565.0 Yes. INCLUDE
# 76.0 1665.0 No. The abstract discusses EXCLUDE
# 77.0 144.0 No. INCLUDE
# 78.0 343.0 Yes. INCLUDE
# 79.0 1748.0 Yes. EXCLUDE
# 80.0 1619.0 The abstract does not mention INCLUDE
# 81.0 1057.0 No. EXCLUDE
# 82.0 890.0 No. EXCLUDE
# 83.0 1659.0 No. EXCLUDE
# 84.0 1543.0 No. EXCLUDE
# 85.0 1216.0 No. EXCLUDE
# 86.0 616.0 No. EXCLUDE
# 87.0 1314.0 No INCLUDE
# 88.0 510.0 Yes (The abstract assess INCLUDE
# 89.0 73.0 No. EXCLUDE
# 90.0 1245.0 Yes INCLUDE
# 91.0 1871.0 No. INCLUDE
# 92.0 1472.0 No. EXCLUDE
# 93.0 371.0 No. INCLUDE
# 94.0 604.0 No. INCLUDE
# 95.0 889.0 No. EXCLUDE
# 96.0 1758.0 Yes INCLUDE
# 97.0 82.0 No. INCLUDE
# 98.0 526.0 No. INCLUDE
# 99.0 1795.0 No. EXCLUDE
# 100.0 1179.0 Yes EXCLUDE
# Wall time: 2min 16s

# %%
train_b12 = chatgpt_train_sample.copy()
train_b12["chatgpt"] = [x[1] for x in responses]
train_b12
# Out:
#        Publication Type                                            Authors  \
# 232.0                 J                   Tang, K; He, CT; Ma, CB; Wang, D
# 1761.0                J  Allam, M; Radicetti, E; Quintarelli, V; Petros...
# 792.0                 J     Raihan, A; Said, MNM; Abdullah, SMS; Begum, RA
# 405.0                 J  Wen, Y; Zang, HD; Freeman, B; Ma, QX; Chadwick...
# 1396.0                J        Dhanda, S; Yadav, A; Yadav, DB; Chauhan, BS
# ...                 ...                                                ...
# 1758.0                J  Carter, MS; Hauggaard-Nielsen, H; Heiske, S; J...
# 82.0                  J               Huang, JX; Chen, YQ; Sui, P; Gao, WS
# 526.0                 J                                         Everest, B
# 1795.0                J                Gancone, A; Pubule, J; Blumberga, D
# 1179.0                J  Tian, Z; Niu, YL; Fan, DL; Sun, LX; Ficsher, G...
#
#                                             Article Title  \
# 232.0   Does carbon farming provide a cost-effective o...
# 1761.0  Influence of Organic and Mineral Fertilizers o...
# 792.0   Climate Change Mitigation Options in the Fores...
# 405.0   Rye cover crop incorporation and high watertab...
# 1396.0  Emerging Issues and Potential Opportunities in...
# ...                                                   ...
# 1758.0  Consequences of field N2O emissions for the en...
# 82.0    Estimation of net greenhouse gas balance using...
# 526.0   Farmers' adaptation to climate-smart agricultu...
# 1795.0  Valorization Methodology for Agriculture Secto...
# 1179.0  Maintaining rice production while mitigating m...
#
#                                             Abstract (AB)  Publication Year  \
# 232.0   In this study, we apply a whole farm bioeconom...            2019.0
# 1761.0  The intensive use of mineral (M) fertilizers m...            2022.0
# 792.0   The Intergovernmental Panel on Climate Change ...            2018.0
# 405.0   Drainage and cultivation of peat soils almost ...            2019.0
# 1396.0  The rice-wheat cropping system (RWCS) is the b...            2022.0
# ...                                                   ...               ...
# 1758.0  One way of reducing the emissions of fossil fu...            2012.0
# 82.0    The net greenhouse gas balance (NGHGB), estima...            2013.0
# 526.0   Some of the measures to be taken to reduce gre...            2021.0
# 1795.0  Agriculture sector holds an essential role in ...            2021.0
# 1179.0  China is the largest rice producing and consum...            2018.0
#
#                                      DOI Researcher1 Researcher2 Researcher3  \
# 232.0            10.1111/1467-8489.12306     INCLUDE         NaN     INCLUDE
# 1761.0       10.3390/agriculture12040464     INCLUDE         NaN     INCLUDE
# 792.0      10.17576/jkukm-2018-si1(6)-11     EXCLUDE         NaN     EXCLUDE
# 405.0                   10.1002/ldr.3390         NaN     INCLUDE     INCLUDE
# 1396.0          10.3389/fpls.2022.832683         NaN     EXCLUDE     EXCLUDE
# ...                                  ...         ...         ...         ...
# 1758.0  10.1111/j.1757-1707.2011.01132.x     INCLUDE         NaN     INCLUDE
# 82.0     10.1016/j.scitotenv.2013.03.035     INCLUDE     INCLUDE         NaN
# 526.0         10.1007/s10668-020-00767-1         NaN     INCLUDE     INCLUDE
# 1795.0          10.2478/rtuect-2021-0071     EXCLUDE         NaN     EXCLUDE
# 1179.0        10.1016/j.agsy.2017.04.006     EXCLUDE     INCLUDE     EXCLUDE
#
#        Final decision Review studies Duplicates                chatgpt
# 232.0         INCLUDE            NaN        NaN  No. The abstract does
# 1761.0        INCLUDE         Review        NaN                    No.
# 792.0         EXCLUDE            NaN        NaN                    No.
# 405.0         INCLUDE            NaN        NaN                   Yes.
# 1396.0        EXCLUDE            NaN        NaN                    No.
# ...               ...            ...        ...                    ...
# 1758.0        INCLUDE            NaN        NaN                    Yes
# 82.0          INCLUDE            NaN        NaN                    No.
# 526.0         INCLUDE            NaN        NaN                    No.
# 1795.0        EXCLUDE            NaN        NaN                    No.
# 1179.0        EXCLUDE            NaN        NaN                    Yes
#
# [100 rows x 13 columns]

# %%
train_b12.to_excel("D:/github/abstract-prediction/chatgpt_responses_b12.xlsx")

# %%
print(classification_report(train_b12["Final decision"] == "INCLUDE", train_b12["chatgpt"].apply(lambda x: int("Yes" in x)), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#        False     0.6620    0.8545    0.7460        55
#         True     0.7241    0.4667    0.5676        45
#
#     accuracy                         0.6800       100
#    macro avg     0.6931    0.6606    0.6568       100
# weighted avg     0.6899    0.6800    0.6657       100

# %%
# %%time
b = "Does the article discuss the impact of methane (CH4) emissions?"
b = b.replace("article", "abstract")
responses = []
for i, ix in enumerate(chatgpt_train_sample.index):
    t, a, label = chatgpt_train_sample.loc[ix]["Article Title  Abstract (AB)  Final decision".split("  ")]
    a = a.replace("\n", " ")
    a = " ".join(a.split(" ")).strip()
    o = chatgpt(template(t, a, b), temp=0.7, max_t=5)["choices"][0]["message"]["content"]
    o = o.replace("\n", " ").strip()
    responses.append([ix, o])
    print(100*(i+1)/chatgpt_train_sample.shape[0], ix, o, label)
# Out:
# 1.0 232.0 Yes. The abstract discusses INCLUDE
# 2.0 1761.0 No. INCLUDE
# 3.0 792.0 No. EXCLUDE
# 4.0 405.0 No INCLUDE
# 5.0 1396.0 Yes. EXCLUDE
# 6.0 433.0 No. EXCLUDE
# 7.0 543.0 No. The abstract only EXCLUDE
# 8.0 412.0 No. INCLUDE
# 9.0 1397.0 No. EXCLUDE
# 10.0 688.0 No. INCLUDE
# 11.0 743.0 No. EXCLUDE
# 12.0 1222.0 No. EXCLUDE
# 13.0 329.0 Yes. EXCLUDE
# 14.0 1365.0 Yes. EXCLUDE
# 15.0 677.0 No. INCLUDE
# 16.0 1432.0 No. INCLUDE
# 17.0 507.0 No. EXCLUDE
# 18.0 1302.0 No. EXCLUDE
# 19.0 847.0 No. INCLUDE
# 20.0 1580.0 No, the abstract does EXCLUDE
# 21.0 1700.0 It is not stated in EXCLUDE
# 22.0 920.0 No. INCLUDE
# 23.0 987.0 Yes INCLUDE
# 24.0 1673.0 No. INCLUDE
# 25.0 312.0 No. INCLUDE
# 26.0 444.0 No. EXCLUDE
# 27.0 1171.0 No. INCLUDE
# 28.0 1448.0 Yes. EXCLUDE
# 29.0 1808.0 Yes. The abstract discusses EXCLUDE
# 30.0 734.0 No. INCLUDE
# 31.0 430.0 Yes. INCLUDE
# 32.0 423.0 No. INCLUDE
# 33.0 718.0 No. EXCLUDE
# 34.0 828.0 No. EXCLUDE
# 35.0 124.0 No. EXCLUDE
# 36.0 1088.0 No. EXCLUDE
# 37.0 1172.0 No. EXCLUDE
# 38.0 38.0 Yes INCLUDE
# 39.0 355.0 Yes. The abstract mentions EXCLUDE
# 40.0 1460.0 No. EXCLUDE
# 41.0 930.0 No. EXCLUDE
# 42.0 574.0 No. EXCLUDE
# 43.0 168.0 No. INCLUDE
# 44.0 362.0 Yes. INCLUDE
# 45.0 1136.0 No. INCLUDE
# 46.0 502.0 Yes EXCLUDE
# 47.0 169.0 No. EXCLUDE
# 48.0 1979.0 No. INCLUDE
# 49.0 324.0 Yes. INCLUDE
# 50.0 1546.0 Yes INCLUDE
# 51.0 1099.0 Yes. INCLUDE
# 52.0 1187.0 Yes. EXCLUDE
# 53.0 892.0 No. EXCLUDE
# 54.0 691.0 Yes. EXCLUDE
# 55.0 1380.0 No. EXCLUDE
# 56.0 1841.0 No. INCLUDE
# 57.0 177.0 No. INCLUDE
# 58.0 1563.0 No. INCLUDE
# 59.0 1893.0 No. EXCLUDE
# 60.0 254.0 Yes. EXCLUDE
# 61.0 34.0 Yes. The abstract discusses EXCLUDE
# 62.0 325.0 No. EXCLUDE
# 63.0 222.0 The abstract does not mention EXCLUDE
# 64.0 1671.0 No. INCLUDE
# 65.0 114.0 The abstract does not explicitly EXCLUDE
# 66.0 126.0 Yes EXCLUDE
# 67.0 215.0 No. INCLUDE
# 68.0 785.0 No. EXCLUDE
# 69.0 894.0 No. The abstract does INCLUDE
# 70.0 1793.0 No. INCLUDE
# 71.0 316.0 No. EXCLUDE
# 72.0 1727.0 Yes. INCLUDE
# 73.0 320.0 No. EXCLUDE
# 74.0 204.0 Yes. The abstract discusses EXCLUDE
# 75.0 565.0 Yes. INCLUDE
# 76.0 1665.0 No. EXCLUDE
# 77.0 144.0 No. INCLUDE
# 78.0 343.0 No. INCLUDE
# 79.0 1748.0 No. EXCLUDE
# 80.0 1619.0 No. INCLUDE
# 81.0 1057.0 Yes. EXCLUDE
# 82.0 890.0 Yes. EXCLUDE
# 83.0 1659.0 Yes (the abstract mentions EXCLUDE
# 84.0 1543.0 Yes. The abstract mentions EXCLUDE
# 85.0 1216.0 No. EXCLUDE
# 86.0 616.0 Yes. EXCLUDE
# 87.0 1314.0 No. INCLUDE
# 88.0 510.0 No. INCLUDE
# 89.0 73.0 Yes EXCLUDE
# 90.0 1245.0 No INCLUDE
# 91.0 1871.0 No. INCLUDE
# 92.0 1472.0 No. EXCLUDE
# 93.0 371.0 Yes. The abstract discusses INCLUDE
# 94.0 604.0 No. INCLUDE
# 95.0 889.0 Yes. EXCLUDE
# 96.0 1758.0 No. INCLUDE
# 97.0 82.0 The abstract does not mention INCLUDE
# 98.0 526.0 No. INCLUDE
# 99.0 1795.0 Yes. EXCLUDE
# 100.0 1179.0 Yes EXCLUDE
# Wall time: 1min 42s

# %%
train_b13 = chatgpt_train_sample.copy()
train_b13["chatgpt"] = [x[1] for x in responses]
train_b13
# Out:
#        Publication Type                                            Authors  \
# 232.0                 J                   Tang, K; He, CT; Ma, CB; Wang, D
# 1761.0                J  Allam, M; Radicetti, E; Quintarelli, V; Petros...
# 792.0                 J     Raihan, A; Said, MNM; Abdullah, SMS; Begum, RA
# 405.0                 J  Wen, Y; Zang, HD; Freeman, B; Ma, QX; Chadwick...
# 1396.0                J        Dhanda, S; Yadav, A; Yadav, DB; Chauhan, BS
# ...                 ...                                                ...
# 1758.0                J  Carter, MS; Hauggaard-Nielsen, H; Heiske, S; J...
# 82.0                  J               Huang, JX; Chen, YQ; Sui, P; Gao, WS
# 526.0                 J                                         Everest, B
# 1795.0                J                Gancone, A; Pubule, J; Blumberga, D
# 1179.0                J  Tian, Z; Niu, YL; Fan, DL; Sun, LX; Ficsher, G...
#
#                                             Article Title  \
# 232.0   Does carbon farming provide a cost-effective o...
# 1761.0  Influence of Organic and Mineral Fertilizers o...
# 792.0   Climate Change Mitigation Options in the Fores...
# 405.0   Rye cover crop incorporation and high watertab...
# 1396.0  Emerging Issues and Potential Opportunities in...
# ...                                                   ...
# 1758.0  Consequences of field N2O emissions for the en...
# 82.0    Estimation of net greenhouse gas balance using...
# 526.0   Farmers' adaptation to climate-smart agricultu...
# 1795.0  Valorization Methodology for Agriculture Secto...
# 1179.0  Maintaining rice production while mitigating m...
#
#                                             Abstract (AB)  Publication Year  \
# 232.0   In this study, we apply a whole farm bioeconom...            2019.0
# 1761.0  The intensive use of mineral (M) fertilizers m...            2022.0
# 792.0   The Intergovernmental Panel on Climate Change ...            2018.0
# 405.0   Drainage and cultivation of peat soils almost ...            2019.0
# 1396.0  The rice-wheat cropping system (RWCS) is the b...            2022.0
# ...                                                   ...               ...
# 1758.0  One way of reducing the emissions of fossil fu...            2012.0
# 82.0    The net greenhouse gas balance (NGHGB), estima...            2013.0
# 526.0   Some of the measures to be taken to reduce gre...            2021.0
# 1795.0  Agriculture sector holds an essential role in ...            2021.0
# 1179.0  China is the largest rice producing and consum...            2018.0
#
#                                      DOI Researcher1 Researcher2 Researcher3  \
# 232.0            10.1111/1467-8489.12306     INCLUDE         NaN     INCLUDE
# 1761.0       10.3390/agriculture12040464     INCLUDE         NaN     INCLUDE
# 792.0      10.17576/jkukm-2018-si1(6)-11     EXCLUDE         NaN     EXCLUDE
# 405.0                   10.1002/ldr.3390         NaN     INCLUDE     INCLUDE
# 1396.0          10.3389/fpls.2022.832683         NaN     EXCLUDE     EXCLUDE
# ...                                  ...         ...         ...         ...
# 1758.0  10.1111/j.1757-1707.2011.01132.x     INCLUDE         NaN     INCLUDE
# 82.0     10.1016/j.scitotenv.2013.03.035     INCLUDE     INCLUDE         NaN
# 526.0         10.1007/s10668-020-00767-1         NaN     INCLUDE     INCLUDE
# 1795.0          10.2478/rtuect-2021-0071     EXCLUDE         NaN     EXCLUDE
# 1179.0        10.1016/j.agsy.2017.04.006     EXCLUDE     INCLUDE     EXCLUDE
#
#        Final decision Review studies Duplicates                        chatgpt
# 232.0         INCLUDE            NaN        NaN    Yes. The abstract discusses
# 1761.0        INCLUDE         Review        NaN                            No.
# 792.0         EXCLUDE            NaN        NaN                            No.
# 405.0         INCLUDE            NaN        NaN                             No
# 1396.0        EXCLUDE            NaN        NaN                           Yes.
# ...               ...            ...        ...                            ...
# 1758.0        INCLUDE            NaN        NaN                            No.
# 82.0          INCLUDE            NaN        NaN  The abstract does not mention
# 526.0         INCLUDE            NaN        NaN                            No.
# 1795.0        EXCLUDE            NaN        NaN                           Yes.
# 1179.0        EXCLUDE            NaN        NaN                            Yes
#
# [100 rows x 13 columns]

# %%
train_b13.to_excel("D:/github/abstract-prediction/chatgpt_responses_b13.xlsx")

# %%
print(classification_report(train_b13["Final decision"] == "INCLUDE", train_b13["chatgpt"].apply(lambda x: int("Yes" in x)), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#        False     0.4925    0.6000    0.5410        55
#         True     0.3333    0.2444    0.2821        45
#
#     accuracy                         0.4400       100
#    macro avg     0.4129    0.4222    0.4115       100
# weighted avg     0.4209    0.4400    0.4245       100

# %%
columns = "Article Title  Abstract (AB)".split("  ")
recols = {"Article Title": "t", "Abstract (AB)": "ab"}
data[columns].rename(columns=recols).to_excel("2000_abstract.xlsx")
