# %%
import pandas as pd
import pickle

# %%
import os
file_names = [] 
for file_name in os.listdir("/home/X/abstracts/"):
    if file_name.startswith("nllf_") and ".xlsx" in file_name:
        file_names.append(file_name)

# %%
data = pd.read_excel("First_2000_abstract_clean.xlsx", index_col=0).reset_index().drop(columns="index")

# %%
nllf = data["Article Title  Abstract (AB)  Final decision".split("  ")].copy()
for file_name in file_names:
    c = "_".join(file_name.split("_")[1:]).split(".")[0]
    o = pd.read_excel(file_name)
    nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
    nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
    nllf
# Out:
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))
# /tmp/ipykernel_4060425/1877773095.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(N)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[0]))
# /tmp/ipykernel_4060425/1877773095.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   nllf[f"{c}(Y)"] = o["chatgpt_label"].apply(lambda x: float(str(x)[1:-1].split()[1]))

# %%
nllf.to_excel("NLLF.xlsx")
