# %%
import pandas as pd
import numpy as np
import pickle
root="data/"

# %%
df = {}
for k in ["train", "val", "test"]:
    df[k] = {}
    for c in ["bong"]:
        df[k][c] = pd.read_excel(root+f"{c}_{k}.xlsx", index_col=0)

# %%
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier

# %%
cols_bong = [c for c in df["train"]["bong"].columns if c not in ["id", "label"]]

X_train = df["train"]["bong"][cols_bong]
X_val = df["val"]["bong"][cols_bong]
X_test = df["test"]["bong"][cols_bong]

X_train = X_train.loc[:, ~X_train.columns.duplicated()]
X_val = X_val.loc[:, ~X_val.columns.duplicated()]
X_test = X_test.loc[:, ~X_test.columns.duplicated()]

y_train = (df["train"]["bong"]["label"]).apply(int)
y_val = (df["val"]["bong"]["label"]).apply(int)
y_test = (df["test"]["bong"]["label"]).apply(int)

# %%
from sklearn_genetic import GAFeatureSelectionCV
import random
# Out:
# 2023-10-21 17:24:35.528562: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from sklearn.model_selection import KFold

# %%
random_seed = 54

np.random.seed(random_seed)
random.seed(random_seed)

train_test_sample = pd.concat([
    pd.concat([X_train, y_train], axis=1), 
    pd.concat([X_val, y_val], axis=1)
    ], ignore_index=True)
train_test_sample

kf = KFold(n_splits=15, random_state=42, shuffle=True)
F_features = []
for i, (train_index, test_index) in enumerate(kf.split(train_test_sample)):
    print(f"Fold {i}:")

    evolved_estimator = GAFeatureSelectionCV(
        estimator=DecisionTreeClassifier(
            random_state=42, 
            max_depth=5, 
            criterion="gini", 
        ),
        cv=[(train_index, test_index)],
        scoring="f1_macro",
        population_size=30,
        generations=5,
        n_jobs=-1,
        verbose=True,
        keep_top_k=2,
        elitism=True,
    )

    support = [x for x in train_test_sample.columns if x not in ["label"]]

    evolved_estimator.fit(pd.DataFrame(train_test_sample.drop(columns="label")[support].values), train_test_sample["label"])

    best_features = [x for i, x in enumerate(train_test_sample.drop(columns="label")[support].columns) if vars(evolved_estimator)["best_features_"][i]]
    F_features += best_features
# Out:
# Fold 0:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.487077	0.0120581  	0.49867    	0.469163
# 1  	60    	0.495847	0.00697735 	0.515873   	0.479763
# 2  	60    	0.499635	0.00672178 	0.524517   	0.488121
# 3  	60    	0.499635	0.0112656  	0.524517   	0.470038
# 4  	60    	0.502543	0.0110299  	0.524517   	0.479388
# 5  	60    	0.501268	0.00931962 	0.515194   	0.47033
# Fold 1:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.474063	0.0109451  	0.491367   	0.456901
# 1  	60    	0.482677	0.00485929 	0.491367   	0.464349
# 2  	60    	0.48201 	0.00667338 	0.491367   	0.457513
# 3  	60    	0.48302 	0.00571149 	0.489838   	0.463652
# 4  	60    	0.482886	0.00584315 	0.489838   	0.464698
# 5  	60    	0.483242	0.0063178  	0.491367   	0.464001
# Fold 2:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.484149	0.0177439  	0.514111   	0.462054
# 1  	60    	0.501271	0.010574   	0.514111   	0.469258
# 2  	60    	0.50392 	0.00610132 	0.514111   	0.477468
# 3  	60    	0.501288	0.0121907  	0.514111   	0.462653
# 4  	60    	0.5012  	0.0129426  	0.514111   	0.469611
# 5  	60    	0.500201	0.0150825  	0.514111   	0.462354
# Fold 3:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.485263	0.0155564  	0.508899   	0.462953
# 1  	60    	0.49744 	0.00976564 	0.515424   	0.471384
# 2  	60    	0.498937	0.00951197 	0.515424   	0.478693
# 3  	60    	0.502593	0.00739928 	0.515424   	0.485787
# 4  	60    	0.499406	0.010318   	0.515424   	0.479104
# 5  	60    	0.50036 	0.0105485  	0.516757   	0.479104
# Fold 4:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.486329	0.0143156  	0.532199   	0.469747
# 1  	60    	0.495271	0.0130549  	0.533015   	0.47033
# 2  	60    	0.497717	0.0102314  	0.516559   	0.470621
# 3  	60    	0.496666	0.0107856  	0.516559   	0.470621
# 4  	60    	0.499462	0.00736362 	0.516559   	0.487672
# 5  	60    	0.506146	0.0103874  	0.516559   	0.470621
# Fold 5:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.478671	0.0126677  	0.502179   	0.463252
# 1  	60    	0.488328	0.0089183  	0.502179   	0.464147
# 2  	60    	0.488691	0.0112773  	0.502179   	0.464147
# 3  	60    	0.493685	0.0097745  	0.508283   	0.463849
# 4  	60    	0.49405 	0.00937291 	0.508283   	0.464147
# 5  	60    	0.494983	0.009603   	0.508283   	0.47174
# Fold 6:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.479394	0.00938293 	0.499554   	0.466814
# 1  	60    	0.4867  	0.00729034 	0.499554   	0.467109
# 2  	60    	0.487803	0.00737127 	0.499554   	0.467109
# 3  	60    	0.48922 	0.00612136 	0.499554   	0.475701
# 4  	60    	0.491321	0.00554566 	0.499554   	0.475701
# 5  	60    	0.487722	0.00762151 	0.499554   	0.474612
# Fold 7:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.490908	0.0183176  	0.524614   	0.463849
# 1  	60    	0.510449	0.0104834  	0.530169   	0.479104
# 2  	60    	0.512085	0.0116001  	0.524614   	0.472097
# 3  	60    	0.511661	0.014512   	0.524614   	0.471384
# 4  	60    	0.513621	0.0105118  	0.524614   	0.479104
# 5  	60    	0.508575	0.0200318  	0.524614   	0.47174
# Fold 8:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.486402	0.0199953  	0.515988   	0.465632
# 1  	60    	0.497125	0.0170574  	0.515988   	0.466814
# 2  	60    	0.508565	0.00230673 	0.515988   	0.506888
# 3  	60    	0.507857	0.00814453 	0.515988   	0.466814
# 4  	60    	0.508781	0.00720874 	0.515988   	0.474251
# 5  	60    	0.503794	0.0138359  	0.515988   	0.466814
# Fold 9:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.483395	0.0200215  	0.523177   	0.462953
# 1  	60    	0.504727	0.0187865  	0.523893   	0.471029
# 2  	60    	0.512295	0.0145893  	0.524614   	0.472097
# 3  	60    	0.516328	0.0120314  	0.524614   	0.472097
# 4  	60    	0.5155  	0.0140345  	0.524614   	0.47174
# 5  	60    	0.51668 	0.0149031  	0.524614   	0.471029
# Fold 10:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.486049	0.0153833  	0.512691   	0.465336
# 1  	60    	0.4981  	0.0092245  	0.51334    	0.47353
# 2  	60    	0.500055	0.0113427  	0.512691   	0.465632
# 3  	60    	0.49695 	0.0117137  	0.51334    	0.472455
# 4  	60    	0.495675	0.00947042 	0.512691   	0.472455
# 5  	60    	0.498723	0.00793257 	0.512691   	0.47389
# Fold 11:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.482934	0.0131591  	0.499361   	0.461753
# 1  	60    	0.491184	0.00894454 	0.499361   	0.469965
# 2  	60    	0.493699	0.00746086 	0.499361   	0.477063
# 3  	60    	0.495373	0.00702593 	0.499361   	0.477063
# 4  	60    	0.496078	0.00580438 	0.499361   	0.477468
# 5  	60    	0.49754 	0.00607733 	0.504671   	0.469965
# Fold 12:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.477234	0.0127151  	0.50058    	0.45838
# 1  	60    	0.487015	0.00959254 	0.506553   	0.4664
# 2  	60    	0.485214	0.0085754  	0.494446   	0.466751
# 3  	60    	0.486741	0.00819161 	0.493919   	0.465699
# 4  	60    	0.489828	0.00563034 	0.493919   	0.47223
# 5  	60    	0.490539	0.00603273 	0.494446   	0.473019
# Fold 13:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.476335	0.00888519 	0.496044   	0.459899
# 1  	60    	0.479897	0.00846103 	0.494976   	0.467102
# 2  	60    	0.484783	0.00717985 	0.496044   	0.474607
# 3  	60    	0.485729	0.00582111 	0.496044   	0.474607
# 4  	60    	0.488164	0.00608225 	0.496583   	0.467453
# 5  	60    	0.488797	0.00836809 	0.501149   	0.460504
# Fold 14:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.502308	0.0224344  	0.542158   	0.463211
# 1  	60    	0.517589	0.0130129  	0.542158   	0.493143
# 2  	60    	0.524178	0.0134508  	0.542158   	0.478653
# 3  	60    	0.530265	0.00734231 	0.542158   	0.507631
# 4  	60    	0.521763	0.0194522  	0.542158   	0.478653
# 5  	60    	0.529167	0.011351   	0.542992   	0.486209

# %%
with open(f'output/bong_features.npy', 'wb') as f:
    o = np.array(F_features)
    np.save(f, o)
