# %%
import pandas as pd

# %%
df = {}
for k in ["train", "val", "test"]:
    df[k] = {}
    for c in ["data", "nllf", "lf"]:
        df[k][c] = pd.read_excel(f"setting/{c}_v2_{k}.xlsx", index_col=0)

# %%
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier

# %%
X_train = df["train"]["nllf"]
X_val = df["val"]["nllf"]
X_test = df["test"]["nllf"]

X_train = X_train.loc[:, ~X_train.columns.duplicated()]
X_val = X_val.loc[:, ~X_val.columns.duplicated()]
X_test = X_test.loc[:, ~X_test.columns.duplicated()]

y_train = (df["train"]["data"]["Final decision"] == "INCLUDE").apply(int)
y_val = (df["val"]["data"]["Final decision"] == "INCLUDE").apply(int)
y_test = (df["test"]["data"]["Final decision"] == "INCLUDE").apply(int)

# %%
from sklearn_genetic import GAFeatureSelectionCV
import numpy as np
import random
# Out:
# 2023-10-21 17:22:48.896420: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from sklearn.model_selection import KFold

# %%
random_seed = 54

np.random.seed(random_seed)
random.seed(random_seed)

train_test_sample = pd.concat([
    pd.concat([X_train, y_train], axis=1), 
    pd.concat([X_val, y_val], axis=1)
    ], ignore_index=True)
train_test_sample

kf = KFold(n_splits=15, random_state=42, shuffle=True)
F_features = []
for i, (train_index, test_index) in enumerate(kf.split(train_test_sample)):
    print(f"Fold {i}:")

    evolved_estimator = GAFeatureSelectionCV(
        estimator=DecisionTreeClassifier(
            random_state=42, 
            max_depth=5, 
            criterion="gini", 
        ),
        cv=[(train_index, test_index)],
        scoring="f1_macro",
        population_size=30,
        generations=10,
        n_jobs=-1,
        verbose=True,
        keep_top_k=2,
        elitism=True,
    )

    support = [x for x in train_test_sample.columns if x not in ["Final decision"] and x[0] in ["b"]]

    evolved_estimator.fit(pd.DataFrame(train_test_sample.drop(columns="Final decision")[support].values), train_test_sample["Final decision"])

    best_features = [x for i, x in enumerate(train_test_sample.drop(columns="Final decision")[support].columns) if vars(evolved_estimator)["best_features_"][i]]
    F_features += best_features
# Out:
# Fold 0:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.650458	0.0215086  	0.700908   	0.607442
# 1  	60    	0.665909	0.0142724  	0.70028    	0.633465
# 2  	60    	0.672611	0.0223039  	0.707728   	0.606618
# 3  	60    	0.681417	0.0117988  	0.70028    	0.651159
# 4  	60    	0.686806	0.0224016  	0.762286   	0.642329
# 5  	60    	0.696188	0.0307086  	0.762286   	0.644829
# 6  	60    	0.706373	0.0343031  	0.762286   	0.653722
# 7  	60    	0.700775	0.0338943  	0.762286   	0.643333
# 8  	60    	0.70641 	0.0319333  	0.753369   	0.654206
# 9  	60    	0.703916	0.0293565  	0.753369   	0.654839
# 10 	60    	0.697265	0.0274696  	0.753369   	0.661154
# Fold 1:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.633153	0.0284846  	0.682215   	0.563652
# 1  	60    	0.645241	0.0172173  	0.682215   	0.606618
# 2  	60    	0.654241	0.0175603  	0.688871   	0.624561
# 3  	60    	0.654215	0.0211635  	0.69774    	0.616286
# 4  	60    	0.66971 	0.0226813  	0.719013   	0.627178
# 5  	60    	0.674541	0.0265126  	0.719013   	0.627178
# 6  	60    	0.676515	0.0233898  	0.719013   	0.627178
# 7  	60    	0.682027	0.0211548  	0.719013   	0.626136
# 8  	60    	0.688285	0.0204016  	0.728117   	0.652262
# 9  	60    	0.680376	0.030089   	0.728117   	0.62535
# 10 	60    	0.67227 	0.0292143  	0.717628   	0.607168
# Fold 2:
# gen	nevals	fitness	fitness_std	fitness_max	fitness_min
# 0  	30    	0

# gen	nevals	fitness	fitness_std	fitness_max	fitness_min
# 0  	30    	0.57641	0.0241719  	0.632043   	0.532704
# 1  	60    	0.601183	0.0234439  	0.643811   	0.566038
# 2  	60    	0.606262	0.0221853  	0.643811   	0.560404
# 3  	60    	0.612143	0.0214109  	0.666217   	0.560404
# 4  	60    	0.618358	0.0181179  	0.666217   	0.565419
# 5  	60    	0.618176	0.0233482  	0.666217   	0.566038
# 6  	60    	0.620385	0.0215393  	0.666217   	0.572389
# 7  	60    	0.624593	0.0186025  	0.666217   	0.574525
# 8  	60    	0.617098	0.0255022  	0.641382   	0.54717
# 9  	60    	0.622195	0.0205635  	0.643811   	0.582528
# 10 	60    	0.624286	0.018215   	0.641382   	0.584314
# Fold 12:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.658718	0.0374357  	0.735      	0.582528
# 1  	60    	0.708901	0.0301563  	0.745079   	0.664769
# 2  	60    	0.71576 	0.0275975  	0.745079   	0.612897
# 3  	60    	0.713284	0.0228503  	0.745079   	0.660256
# 4  	60    	0.70881 	0.0265564  	0.745079   	0.659286
# 5  	60    	0.713996	0.0259506  	0.745079   	0.655968
# 6  	60    	0.71383 	0.0231571  	0.745079   	0.657328
# 7  	60    	0.716579	0.0236904  	0.745079   	0.664769
# 8  	60    	0.709332	0.0235977  	0.745079   	0.664807
# 9  	60    	0.713838	0.0216346  	0.745079   	0.652459
# 10 	60    	0.721027	0.0158057  	0.745079   	0.695402
# Fold 13:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.640284	0.0220136  	0.696384   	0.584314
# 1  	60    	0.671479	0.0207746  	0.716578   	0.619253
# 2  	60    	0.676979	0.0192232  	0.716578   	0.640998
# 3  	60    	0.670207	0.0206252  	0.707521   	0.629404
# 4  	60    	0.678306	0.0182174  	0.707521   	0.629404
# 5  	60    	0.67748 	0.0178853  	0.707521   	0.639456
# 6  	60    	0.682575	0.0184814  	0.707521   	0.639456
# 7  	60    	0.688717	0.0218783  	0.725217   	0.63829
# 8  	60    	0.687482	0.0237757  	0.725217   	0.630464
# 9  	60    	0.696444	0.0217847  	0.725217   	0.639456
# 10 	60    	0.697383	0.0236028  	0.725217   	0.640357
# Fold 14:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.621019	0.0310095  	0.669782   	0.51363
# 1  	60    	0.639275	0.0171954  	0.669782   	0.596739
# 2  	60    	0.647231	0.0189097  	0.677408   	0.603632
# 3  	60    	0.658779	0.0246465  	0.698113   	0.610399
# 4  	60    	0.658639	0.0201517  	0.698113   	0.631255
# 5  	60    	0.652339	0.0230722  	0.698113   	0.612345
# 6  	60    	0.658108	0.0263321  	0.698113   	0.6025
# 7  	60    	0.666277	0.0238581  	0.71536    	0.622103
# 8  	60    	0.670546	0.0281913  	0.707521   	0.584906
# 9  	60    	0.662993	0.0277379  	0.707521   	0.594304
# 10 	60    	0.672553	0.0276995  	0.707521   	0.612897

# %%
with open(f'output/nllf_features.npy', 'wb') as f:
    o = np.array(F_features)
    np.save(f, o)
