# %%
import pandas as pd

# %%
df = {}
for k in ["train", "val", "test"]:
    df[k] = {}
    for c in ["data", "bong"]:
        df[k][c] = pd.read_excel(f"setting/{c}_v2_{k}.xlsx", index_col=0)

# %%
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier

# %%
X_train = df["train"]["bong"]
X_val = df["val"]["bong"]
X_test = df["test"]["bong"]

X_train = X_train.loc[:, ~X_train.columns.duplicated()]
X_val = X_val.loc[:, ~X_val.columns.duplicated()]
X_test = X_test.loc[:, ~X_test.columns.duplicated()]

y_train = (df["train"]["data"]["Final decision"] == "INCLUDE").apply(int)
y_val = (df["val"]["data"]["Final decision"] == "INCLUDE").apply(int)
y_test = (df["test"]["data"]["Final decision"] == "INCLUDE").apply(int)

# %%
from sklearn_genetic import GAFeatureSelectionCV
import numpy as np
import random
# Out:
# 2023-10-21 17:22:20.993918: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from sklearn.model_selection import KFold

# %%
random_seed = 54

np.random.seed(random_seed)
random.seed(random_seed)

train_test_sample = pd.concat([
    pd.concat([X_train, y_train], axis=1), 
    pd.concat([X_val, y_val], axis=1)
    ], ignore_index=True)
train_test_sample

kf = KFold(n_splits=15, random_state=42, shuffle=True)
F_features = []
for i, (train_index, test_index) in enumerate(kf.split(train_test_sample)):
    print(f"Fold {i}:")

    evolved_estimator = GAFeatureSelectionCV(
        estimator=DecisionTreeClassifier(
            random_state=42, 
            max_depth=5, 
            criterion="gini", 
        ),
        cv=[(train_index, test_index)],
        scoring="f1_macro",
        population_size=30,
        generations=10,
        n_jobs=-1,
        verbose=True,
        keep_top_k=2,
        elitism=True,
    )

    support = [x for x in train_test_sample.columns if x not in ["Final decision"]]

    evolved_estimator.fit(pd.DataFrame(train_test_sample.drop(columns="Final decision")[support].values), train_test_sample["Final decision"])

    best_features = [x for i, x in enumerate(train_test_sample.drop(columns="Final decision")[support].columns) if vars(evolved_estimator)["best_features_"][i]]
    F_features += best_features
# Out:
# Fold 0:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.618411	0.0391128  	0.700699   	0.549474
# 1  	60    	0.685155	0.0379312  	0.738295   	0.587885
# 2  	60    	0.687462	0.0379756  	0.754414   	0.607442
# 3  	60    	0.688484	0.0339617  	0.754414   	0.616286
# 4  	60    	0.700262	0.0300808  	0.754414   	0.635387
# 5  	60    	0.692401	0.0413004  	0.754414   	0.607442
# 6  	60    	0.700378	0.0436278  	0.754414   	0.62535
# 7  	60    	0.71801 	0.0382481  	0.783153   	0.635004
# 8  	60    	0.691626	0.0491951  	0.783153   	0.611192
# 9  	60    	0.710215	0.0479424  	0.783153   	0.639539
# 10 	60    	0.700846	0.0388811  	0.783153   	0.64458
# Fold 1:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.661204	0.0241653  	0.722773   	0.624899
# 1  	60    	0.67836 	0.0249342  	0.722773   	0.635004
# 2  	60    	0.695019	0.0233858  	0.738112   	0.657051
# 3  	60    	0.688494	0.0226821  	0.738112   	0.643333
# 4  	60    	0.695743	0.0234376  	0.738112   	0.632302
# 5  	60    	0.701432	0.0187428  	0.738112   	0.669513
# 6  	60    	0.706371	0.0200325  	0.738112   	0.642329
# 7  	60    	0.70348 	0.0230185  	0.740315   	0.643333
# 8  	60    	0.716759	0.0216445  	0.766028   	0.651159
# 9  	60    	0.716619	0.0297728  	0.766028   	0.647253
# 10 	60    	0.723927	0.024479   	0.766028   	0.661154
# Fold 2:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0

# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.596074	0.0495029  	0.707313   	0.51363
# 1  	60    	0.640853	0.0310779  	0.707313   	0.575131
# 2  	60    	0.647366	0.0293657  	0.707313   	0.565883
# 3  	60    	0.653278	0.0326935  	0.707313   	0.556564
# 4  	60    	0.660295	0.0298244  	0.696384   	0.556564
# 5  	60    	0.659928	0.0281951  	0.696384   	0.591394
# 6  	60    	0.671545	0.0177505  	0.697143   	0.629404
# 7  	60    	0.672317	0.0229468  	0.706266   	0.622103
# 8  	60    	0.674316	0.0235465  	0.697143   	0.592009
# 9  	60    	0.671567	0.0293767  	0.697143   	0.592009
# 10 	60    	0.667508	0.0400293  	0.716578   	0.564264
# Fold 12:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.627112	0.0437021  	0.699826   	0.537365
# 1  	60    	0.666151	0.0391731  	0.733477   	0.565883
# 2  	60    	0.688562	0.0250251  	0.733477   	0.62048
# 3  	60    	0.6917  	0.0261187  	0.733477   	0.63829
# 4  	60    	0.696892	0.0248999  	0.733477   	0.63829
# 5  	60    	0.69027 	0.0342362  	0.733477   	0.593435
# 6  	60    	0.692749	0.0293194  	0.74251    	0.593435
# 7  	60    	0.689636	0.0292644  	0.74251    	0.603209
# 8  	60    	0.692096	0.032818   	0.74251    	0.577767
# 9  	60    	0.699043	0.0262868  	0.74251    	0.645613
# 10 	60    	0.697514	0.0257743  	0.74251    	0.631255
# Fold 13:
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	30    	0.622591	0.0379704  	0.695402   	0.52829
# 1  	60    	0.656982	0.0273507  	0.698006   	0.612345
# 2  	60    	0.67415 	0.016861   	0.698006   	0.632043
# 3  	60    	0.676238	0.0174369  	0.723437   	0.630464
# 4  	60    	0.676721	0.0143778  	0.723437   	0.650912
# 5  	60    	0.684648	0.0212827  	0.723437   	0.632043
# 6  	60    	0.687352	0.0207366  	0.723437   	0.62807
# 7  	60    	0.680923	0.0259196  	0.723437   	0.617743
# 8  	60    	0.689886	0.0262231  	0.723437   	0.62807
# 9  	60    	0.687384	0.0209276  	0.723437   	0.645613
# 10 	60    	0.68951 	0.0221727  	0.725805   	0.641382
# Fold 14:
# gen	nevals	fitness	fitness_std	fitness_max	fitness_min
# 0  	30    	0.61959	0.0404462  	0.706266   	0.5256
# 1  	60    	0.659693	0.0316588  	0.73242    	0.603774
# 2  	60    	0.675511	0.0306681  	0.73242    	0.622103
# 3  	60    	0.684946	0.0253411  	0.73242    	0.622362
# 4  	60    	0.696846	0.0168904  	0.73242    	0.641509
# 5  	60    	0.704306	0.0144093  	0.73242    	0.663064
# 6  	60    	0.695177	0.0266019  	0.723437   	0.615942
# 7  	60    	0.701607	0.020423   	0.723437   	0.640357
# 8  	60    	0.712956	0.0218313  	0.748998   	0.62807
# 9  	60    	0.714385	0.0197381  	0.748998   	0.647841
# 10 	60    	0.706691	0.0327918  	0.748998   	0.640998

# %%
with open(f'output/bong_features.npy', 'wb') as f:
    o = np.array(F_features)
    np.save(f, o)
